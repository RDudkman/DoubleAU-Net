# %% [markdown]
# 🧑**Roe Barlev**
#
# 🧑**Ron Dudkman**

# %% [markdown]
# NOTE: The model’s name in our code is called DoubleUNet because we first implemented the DoubleUNet and on top of the base notebook we added our changes. We didn’t change the variable’s name when we implemented our DoubleAU-Net. **To be clear, the model in the notebook is our DoubleAU-Net.**

# %% [markdown]
# # 1 Setup

# %% [markdown]
# Connect to drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# !nvidia-smi -L
# Out:
# Mounted at /content/gdrive
# GPU 0: Tesla T4 (UUID: GPU-31f80cb6-1463-7eac-7f0a-93a88e9a818c)

# %% [markdown]
# ## 1.1 Libreries

# %%
# !pip install ipyplot
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ipyplot in /usr/local/lib/python3.7/dist-packages (1.1.1)
# Requirement already satisfied: IPython in /usr/local/lib/python3.7/dist-packages (from ipyplot) (7.9.0)
# Requirement already satisfied: shortuuid in /usr/local/lib/python3.7/dist-packages (from ipyplot) (1.0.9)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ipyplot) (1.21.6)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from ipyplot) (7.1.2)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.7/dist-packages (from IPython->ipyplot) (0.18.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from IPython->ipyplot) (0.7.5)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from IPython->ipyplot) (4.8.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from IPython->ipyplot) (2.6.1)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from IPython->ipyplot) (2.0.10)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from IPython->ipyplot) (57.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from IPython->ipyplot) (4.4.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from IPython->ipyplot) (0.2.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from IPython->ipyplot) (5.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.10->IPython->ipyplot) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->IPython->ipyplot) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->IPython->ipyplot) (1.15.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->IPython->ipyplot) (0.7.0)

# %%
import os, cv2
import numpy as np
import pandas as pd
import random, tqdm
import seaborn as sns
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import albumentations as album

import ipyplot
import os.path
import zipfile
from glob import glob
from google.colab.patches import cv2_imshow

from sklearn.model_selection import train_test_split


import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import torchvision
from torchvision.models import vgg19
from torchvision.ops import *
from torch.nn import functional as F
from torch.optim import NAdam, Adam
from torch.optim import lr_scheduler

from datetime import datetime

import pickle

import random
from tqdm import tqdm
import tifffile as tif
from albumentations import (
    PadIfNeeded,
    HorizontalFlip,
    VerticalFlip,
    CenterCrop,
    Crop,
    Compose,
    Transpose,
    RandomRotate90,
    ElasticTransform,
    GridDistortion,
    OpticalDistortion,
    RandomSizedCrop,
    OneOf,
    CLAHE,
    RandomBrightnessContrast,
    RandomGamma,
    HueSaturationValue,
    RGBShift,
    RandomBrightness,
    RandomContrast,
    MotionBlur,
    MedianBlur,
    GaussianBlur,
    GaussNoise,
    ChannelShuffle,
    CoarseDropout
)

from requests import get
from torchsummary import summary

# %% [markdown]
# ## 1.2 Config

# %%
config = {}

# Link for the bowl dataset: https://www.kaggle.com/competitions/data-science-bowl-2018/data
# Link for the CVC dataset : https://www.kaggle.com/datasets/balraj98/cvcclinicdb

##################### Configuration: ######################
''' choose the dataset u want to work with'''
#config['dataset'] = 'bowl'
config['dataset']= 'CVC'

''' choose True if u need to arrange your data for the first time'''
#config['first_time_data_arrangement'] = True
config['first_time_data_arrangement'] = False

''' choose if you want to use the interpolation technique '''
config ['use_interpolation'] = True
#config['use_interpolation']= False


''' change directories paths'''
config['data_path'] = '/content/gdrive/MyDrive/Datasets/'#/content/Datasets/' 
config['output_path'] = '/content/gdrive/MyDrive/output/'#'/content/output/'

#############################################################
config['CVC_ClinicDB_zip_path'] = config['data_path']+'CVC-ClinicDB.zip'
config['bowl_2018_zip_path'] = config['data_path']+'data-science-bowl-2018.zip'
config['bowl_2018_train_zip_path'] = '/content/data-science-bowl-2018/stage1_train.zip'

config['CVC_ClinicDB_new_zip_path'] = config['data_path']+'CVC-ClinicDB-new_data.zip'
config['bowl_2018_new_zip_path'] = config['data_path']+'bowl_dataset-new_data.zip'

if config['dataset']=='bowl':
  config['input_w']=256
  config['input_h']=256
  config['lr'] = lr = 1e-4
  config['batch_size']=16
else:
  config['input_w']=384
  config['input_h']=288 
  config['lr'] = 1e-4
  if config['use_interpolation'] == True:
    config['batch_size']=16
  elif config['use_interpolation'] == False: 
    config ['batch_size']=4 

config['notebook_name'] =  get('http://172.28.0.2:9000/api/sessions').json()[0]['name']

config['name']=None
config['epochs']=30

config['eps'] = 1e-07
config['num_workers']=2
config['squeeze_ratio']=8
config['smooth'] = 1e-15

config['early_stopping_patience'] = 15
config['scheduler_reduce_lr_factor'] = 0.1
config['scheduler_patience'] = 10
#############################################################

# %% [markdown]
# ## 1.3 Utils

# %%
def create_dir(path):
    """ Create a directory. """
    try:
        if not os.path.exists(path):
            os.makedirs(path)
    except OSError:
        print(f"Error: creating directory with name {path}")

# %%
def unzip_by_path(src_zip_path, dest_unzip_path="/content/"):
  
  src_zip_name = src_zip_path.split('.')[0].split('/')[-1] #takes the first name before the .zip ending
  dest_unzip_path = dest_unzip_path + src_zip_name 

  with zipfile.ZipFile(src_zip_path, 'r') as zip_ref:
    zip_ref.extractall(dest_unzip_path)

# %%
def print_both(*args,output_file_path):
    output_file = open(output_file_path, "a") #open file to save all prints to it
    toprint = ' '.join([str(arg) for arg in args])
    print(toprint)
    output_file.write(toprint)
    output_file.close()

# %%
def dict_to_txt(dict_,output_file_path):
  ''' save dict to txt file'''

  output_file = open(output_file_path, "w") #open file to save all prints to it
  for dict_ele in str(dict_).split(','):
    output_file.write(str(dict_ele)+'\n')
  output_file.close()

# %%
def save_list(list_,output_path):
  with open(output_path, "wb") as fp:   #Pickling
    pickle.dump(list_, fp)
    fp.close()


def load_list(output_path):
  with open(output_path, "rb") as fp:   # Unpickling
    list_ = pickle.load(fp)
    fp.close()
  
  return list_

# %% [markdown]
# # 2 Datasets extraction to local env

# %% [markdown]
# Extract Datasets to local workspace

# %%
src_zip_paths = [config['CVC_ClinicDB_zip_path'],
                 config['bowl_2018_zip_path'],
                 config['bowl_2018_train_zip_path'],
                 config['CVC_ClinicDB_new_zip_path'],
                 config['bowl_2018_new_zip_path']]

if config['first_time_data_arrangement']: # if it is the first time foro creating the zip new data
  if config['dataset']=='bowl':
    unzip_by_path(src_zip_paths[1], dest_unzip_path="/content/")
    unzip_by_path(src_zip_paths[2], dest_unzip_path="/content/bowl_dataset/") 
  else:
    unzip_by_path(src_zip_paths[0], dest_unzip_path="/content/")

elif not config['first_time_data_arrangement']: #when you have the new data just unzip it to this location
  if config['dataset']=='bowl':
    unzip_by_path(src_zip_paths[4], dest_unzip_path="/content/") 
  else:
    unzip_by_path(src_zip_paths[3], dest_unzip_path="/content/")

# %% [markdown]
# #3 CVC-ClinicDB

# %% [markdown]
# ##3.1 Utils for this dataset

# %%
def load_data(images_folder_path, masks_folder_path):
  '''load the data to 2 path lists for images and masks.'''

  images = [images_folder_path+name for name in os.listdir(images_folder_path)]
  masks = [masks_folder_path+name for name in os.listdir(masks_folder_path)]
  return images, masks

def read_data_to_list(images_path, masks_path):
    """ Read the image and mask from the given images and masks lists of paths. """

    images = []
    masks =[]
    for xi,yi in zip(images_path,masks_path):
      images.append(cv2.imread(xi, cv2.IMREAD_COLOR))
      masks.append(cv2.imread(yi, cv2.IMREAD_COLOR))
    return images, masks

def split_data(images,masks):
  ''' split the data to 80-10-10'''
  train_size=int(0.8*len(images))
  valid_size=int(0.1*len(images))
  test_size=int(0.1*len(images))
  
  train_x, test_x = train_test_split(images, test_size=test_size, random_state=0)
  train_y, test_y = train_test_split(masks, test_size=test_size, random_state=0)

  train_x, valid_x = train_test_split(train_x, test_size=valid_size, random_state=0)
  train_y, valid_y = train_test_split(train_y, test_size=valid_size, random_state=0)

  return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)
    
def read_data(x, y):
    """ Read the image and mask from the given path. """
    image = cv2.imread(x, cv2.IMREAD_COLOR)
    mask = cv2.imread(y, cv2.IMREAD_COLOR)
    return image, mask

# %% [markdown]
# ##3.2 Read and learn the data

# %% [markdown]
# Read images and masks paths & read images and masks as images

# %%
if config['first_time_data_arrangement']:
  CVC_images_path, CVC_masks_path = load_data("/content/CVC-ClinicDB/PNG/Original/", "/content/CVC-ClinicDB/PNG/Ground Truth/")
  CVC_images, CVC_masks = read_data_to_list(CVC_images_path, CVC_masks_path)

  print("Numbers of images for CVC-ClinicDB: " + str(len(CVC_images)))
  print("Numbers of masks for CVC-ClinicDB: " + str(len(CVC_masks_path)))
# Out:
# Numbers of images for CVC-ClinicDB: 612
# Numbers of masks for CVC-ClinicDB: 612

# %% [markdown]
# Images shape check

# %%
if config['first_time_data_arrangement']:
  check_images_shape = {img.shape for img in CVC_images} #create a set of values, if we get 1 element it means all images are the same size
  print("images shape is (H,W,C):"+str(check_images_shape))
  check_masks_shape = {mask.shape for mask in CVC_masks} #create a set of values, if we get 1 element it means all images are the same size
  print("masks shape is (H,W,C):"+str(check_masks_shape))
# Out:
# images shape is (H,W,C):{(288, 384, 3)}
# masks shape is (H,W,C):{(288, 384, 3)}

# %% [markdown]
# ## 3.3 Split the data

# %%
if config['first_time_data_arrangement']:
  (CVC_train_images_path, CVC_train_masks_path), (CVC_valid_images_path, CVC_valid_masks_path), (CVC_test_images_path, CVC_test_masks_path) = split_data(CVC_images_path,CVC_masks_path)
  print("Numbers of CVC_train_images: " + str(len(CVC_train_images_path)))
  print("Numbers of CVC_valid_images: " + str(len(CVC_valid_images_path)))
  print("Numbers of CVC_test_images: " + str(len(CVC_test_images_path)))
  print("Numbers of CVC_train_masks: " + str(len(CVC_train_masks_path)))
  print("Numbers of CVC_valid_masks: " + str(len(CVC_valid_masks_path)))
  print("Numbers of CVC_test_masks: " + str(len(CVC_test_masks_path)))
# Out:
# Numbers of CVC_train_images: 490
# Numbers of CVC_valid_images: 61
# Numbers of CVC_test_images: 61
# Numbers of CVC_train_masks: 490
# Numbers of CVC_valid_masks: 61
# Numbers of CVC_test_masks: 61

# %% [markdown]
# ## 3.4 Data examples

# %% [markdown]
# Show the data by images and masks

# %%
if config['first_time_data_arrangement']:
  ipyplot.plot_images(CVC_images, max_images=7, img_width=150, force_b64=True)
  ipyplot.plot_images(CVC_masks, max_images=7, img_width=150, force_b64=True)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-LsXvWgHKzHfYeB9ZiXdB4e {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-LsXvWgHKzHfYeB9ZiXdB4e {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-LsXvWgHKzHfYeB9ZiXdB4e {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-LsXvWgHKzHfYeB9ZiXdB4e:checked ~ #ipyplot-html-viewer-textarea-LsXvWgHKzHfYeB9ZiXdB4e {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-LsXvWgHKzHfYeB9ZiXdB4e:checked + #ipyplot-html-viewer-label-LsXvWgHKzHfYeB9ZiXdB4e:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-LsXvWgHKzHfYeB9ZiXdB4e">
#         <label id="ipyplot-html-viewer-label-LsXvWgHKzHfYeB9ZiXdB4e" for="ipyplot-html-viewer-toggle-LsXvWgHKzHfYeB9ZiXdB4e">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-LsXvWgHKzHfYeB9ZiXdB4e" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-bQMPnVGyKdnjZcjik3uFh7 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-bQMPnVGyKdnjZcjik3uFh7 {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7 {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7 img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-bQMPnVGyKdnjZcjik3uFh7">
#     <div class="ipyplot-placeholder-div-bQMPnVGyKdnjZcjik3uFh7">
#         <div id="ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7-4begEbXTJE5VF8iqECSCbP" class="ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7-4begEbXTJE5VF8iqECSCbP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bQMPnVGyKdnjZcjik3uFh7">
#         <div id="ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7-g9GDpRpKnjD3xd27SjMKNF" class="ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7-g9GDpRpKnjD3xd27SjMKNF">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bQMPnVGyKdnjZcjik3uFh7">
#         <div id="ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7-R35e4MxBRGMPqzHTLDmNcA" class="ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7-R35e4MxBRGMPqzHTLDmNcA">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bQMPnVGyKdnjZcjik3uFh7">
#         <div id="ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7-CRBfg7zHwUqaKvQ58b5tvC" class="ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7-CRBfg7zHwUqaKvQ58b5tvC">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bQMPnVGyKdnjZcjik3uFh7">
#         <div id="ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7-DNUEZa2NgrUyjw8LWfYh4a" class="ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7-DNUEZa2NgrUyjw8LWfYh4a">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bQMPnVGyKdnjZcjik3uFh7">
#         <div id="ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7-hCgyzK9Adtkm2ekoQZHvFG" class="ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7-hCgyzK9Adtkm2ekoQZHvFG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bQMPnVGyKdnjZcjik3uFh7">
#         <div id="ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7-dz5UhRfKoTGB5fPbDvSrQf" class="ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7-dz5UhRfKoTGB5fPbDvSrQf">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-bQMPnVGyKdnjZcjik3uFh7 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-bQMPnVGyKdnjZcjik3uFh7 {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7 {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7 img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-bQMPnVGyKdnjZcjik3uFh7">
#     <div class="ipyplot-placeholder-div-bQMPnVGyKdnjZcjik3uFh7">
#         <div id="ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7-4begEbXTJE5VF8iqECSCbP" class="ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7-4begEbXTJE5VF8iqECSCbP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bQMPnVGyKdnjZcjik3uFh7">
#         <div id="ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7-g9GDpRpKnjD3xd27SjMKNF" class="ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7-g9GDpRpKnjD3xd27SjMKNF">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bQMPnVGyKdnjZcjik3uFh7">
#         <div id="ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7-R35e4MxBRGMPqzHTLDmNcA" class="ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7-R35e4MxBRGMPqzHTLDmNcA">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bQMPnVGyKdnjZcjik3uFh7">
#         <div id="ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7-CRBfg7zHwUqaKvQ58b5tvC" class="ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7-CRBfg7zHwUqaKvQ58b5tvC">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bQMPnVGyKdnjZcjik3uFh7">
#         <div id="ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7-DNUEZa2NgrUyjw8LWfYh4a" class="ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7-DNUEZa2NgrUyjw8LWfYh4a">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bQMPnVGyKdnjZcjik3uFh7">
#         <div id="ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7-hCgyzK9Adtkm2ekoQZHvFG" class="ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7-hCgyzK9Adtkm2ekoQZHvFG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-bQMPnVGyKdnjZcjik3uFh7">
#         <div id="ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7-dz5UhRfKoTGB5fPbDvSrQf" class="ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-bQMPnVGyKdnjZcjik3uFh7-dz5UhRfKoTGB5fPbDvSrQf">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#     <style>
#         #ipyplot-html-viewer-toggle-LpVcYCDn9RtEzkNUCVmm4u {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-LpVcYCDn9RtEzkNUCVmm4u {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-LpVcYCDn9RtEzkNUCVmm4u {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-LpVcYCDn9RtEzkNUCVmm4u:checked ~ #ipyplot-html-viewer-textarea-LpVcYCDn9RtEzkNUCVmm4u {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-LpVcYCDn9RtEzkNUCVmm4u:checked + #ipyplot-html-viewer-label-LpVcYCDn9RtEzkNUCVmm4u:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-LpVcYCDn9RtEzkNUCVmm4u">
#         <label id="ipyplot-html-viewer-label-LpVcYCDn9RtEzkNUCVmm4u" for="ipyplot-html-viewer-toggle-LpVcYCDn9RtEzkNUCVmm4u">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-LpVcYCDn9RtEzkNUCVmm4u" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-FansPfpAFpqCxym65TiFq3 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-FansPfpAFpqCxym65TiFq3 {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-FansPfpAFpqCxym65TiFq3 {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FansPfpAFpqCxym65TiFq3 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-FansPfpAFpqCxym65TiFq3 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FansPfpAFpqCxym65TiFq3 img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-FansPfpAFpqCxym65TiFq3 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-FansPfpAFpqCxym65TiFq3 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-FansPfpAFpqCxym65TiFq3]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-FansPfpAFpqCxym65TiFq3]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-FansPfpAFpqCxym65TiFq3]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-FansPfpAFpqCxym65TiFq3">
#     <div class="ipyplot-placeholder-div-FansPfpAFpqCxym65TiFq3">
#         <div id="ipyplot-content-div-FansPfpAFpqCxym65TiFq3-5ue8bTFS6Te7LAB4EzJbKU" class="ipyplot-content-div-FansPfpAFpqCxym65TiFq3">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FansPfpAFpqCxym65TiFq3-5ue8bTFS6Te7LAB4EzJbKU">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FansPfpAFpqCxym65TiFq3">
#         <div id="ipyplot-content-div-FansPfpAFpqCxym65TiFq3-QoNXbvJrWzYXLY4DUe2eFt" class="ipyplot-content-div-FansPfpAFpqCxym65TiFq3">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FansPfpAFpqCxym65TiFq3-QoNXbvJrWzYXLY4DUe2eFt">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FansPfpAFpqCxym65TiFq3">
#         <div id="ipyplot-content-div-FansPfpAFpqCxym65TiFq3-TfkpNzBTH7MM6JiriX2UcA" class="ipyplot-content-div-FansPfpAFpqCxym65TiFq3">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FansPfpAFpqCxym65TiFq3-TfkpNzBTH7MM6JiriX2UcA">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FansPfpAFpqCxym65TiFq3">
#         <div id="ipyplot-content-div-FansPfpAFpqCxym65TiFq3-GQEt83mrgq8Q6sqDSgsdUk" class="ipyplot-content-div-FansPfpAFpqCxym65TiFq3">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FansPfpAFpqCxym65TiFq3-GQEt83mrgq8Q6sqDSgsdUk">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FansPfpAFpqCxym65TiFq3">
#         <div id="ipyplot-content-div-FansPfpAFpqCxym65TiFq3-A7jvdeuvURq56UfGq2tSFk" class="ipyplot-content-div-FansPfpAFpqCxym65TiFq3">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FansPfpAFpqCxym65TiFq3-A7jvdeuvURq56UfGq2tSFk">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FansPfpAFpqCxym65TiFq3">
#         <div id="ipyplot-content-div-FansPfpAFpqCxym65TiFq3-3qAtUMa4ctz2oTB5RCiTxs" class="ipyplot-content-div-FansPfpAFpqCxym65TiFq3">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FansPfpAFpqCxym65TiFq3-3qAtUMa4ctz2oTB5RCiTxs">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FansPfpAFpqCxym65TiFq3">
#         <div id="ipyplot-content-div-FansPfpAFpqCxym65TiFq3-jp8cLZc7fovXGthpARqmqu" class="ipyplot-content-div-FansPfpAFpqCxym65TiFq3">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FansPfpAFpqCxym65TiFq3-jp8cLZc7fovXGthpARqmqu">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-FansPfpAFpqCxym65TiFq3 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-FansPfpAFpqCxym65TiFq3 {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-FansPfpAFpqCxym65TiFq3 {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FansPfpAFpqCxym65TiFq3 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-FansPfpAFpqCxym65TiFq3 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-FansPfpAFpqCxym65TiFq3 img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-FansPfpAFpqCxym65TiFq3 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-FansPfpAFpqCxym65TiFq3 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-FansPfpAFpqCxym65TiFq3]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-FansPfpAFpqCxym65TiFq3]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-FansPfpAFpqCxym65TiFq3]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-FansPfpAFpqCxym65TiFq3">
#     <div class="ipyplot-placeholder-div-FansPfpAFpqCxym65TiFq3">
#         <div id="ipyplot-content-div-FansPfpAFpqCxym65TiFq3-5ue8bTFS6Te7LAB4EzJbKU" class="ipyplot-content-div-FansPfpAFpqCxym65TiFq3">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FansPfpAFpqCxym65TiFq3-5ue8bTFS6Te7LAB4EzJbKU">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FansPfpAFpqCxym65TiFq3">
#         <div id="ipyplot-content-div-FansPfpAFpqCxym65TiFq3-QoNXbvJrWzYXLY4DUe2eFt" class="ipyplot-content-div-FansPfpAFpqCxym65TiFq3">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FansPfpAFpqCxym65TiFq3-QoNXbvJrWzYXLY4DUe2eFt">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FansPfpAFpqCxym65TiFq3">
#         <div id="ipyplot-content-div-FansPfpAFpqCxym65TiFq3-TfkpNzBTH7MM6JiriX2UcA" class="ipyplot-content-div-FansPfpAFpqCxym65TiFq3">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FansPfpAFpqCxym65TiFq3-TfkpNzBTH7MM6JiriX2UcA">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FansPfpAFpqCxym65TiFq3">
#         <div id="ipyplot-content-div-FansPfpAFpqCxym65TiFq3-GQEt83mrgq8Q6sqDSgsdUk" class="ipyplot-content-div-FansPfpAFpqCxym65TiFq3">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FansPfpAFpqCxym65TiFq3-GQEt83mrgq8Q6sqDSgsdUk">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FansPfpAFpqCxym65TiFq3">
#         <div id="ipyplot-content-div-FansPfpAFpqCxym65TiFq3-A7jvdeuvURq56UfGq2tSFk" class="ipyplot-content-div-FansPfpAFpqCxym65TiFq3">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FansPfpAFpqCxym65TiFq3-A7jvdeuvURq56UfGq2tSFk">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FansPfpAFpqCxym65TiFq3">
#         <div id="ipyplot-content-div-FansPfpAFpqCxym65TiFq3-3qAtUMa4ctz2oTB5RCiTxs" class="ipyplot-content-div-FansPfpAFpqCxym65TiFq3">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FansPfpAFpqCxym65TiFq3-3qAtUMa4ctz2oTB5RCiTxs">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FansPfpAFpqCxym65TiFq3">
#         <div id="ipyplot-content-div-FansPfpAFpqCxym65TiFq3-jp8cLZc7fovXGthpARqmqu" class="ipyplot-content-div-FansPfpAFpqCxym65TiFq3">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FansPfpAFpqCxym65TiFq3-jp8cLZc7fovXGthpARqmqu">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# Show images and masks by paths

# %%
if config['first_time_data_arrangement']:
  ipyplot.plot_images(CVC_train_images_path, max_images=7, img_width=150, force_b64=True)
  ipyplot.plot_images(CVC_train_masks_path, max_images=7, img_width=150, force_b64=True)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-oHPR4aFarS4rssRjGuJGoS {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-oHPR4aFarS4rssRjGuJGoS {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-oHPR4aFarS4rssRjGuJGoS {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-oHPR4aFarS4rssRjGuJGoS:checked ~ #ipyplot-html-viewer-textarea-oHPR4aFarS4rssRjGuJGoS {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-oHPR4aFarS4rssRjGuJGoS:checked + #ipyplot-html-viewer-label-oHPR4aFarS4rssRjGuJGoS:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-oHPR4aFarS4rssRjGuJGoS">
#         <label id="ipyplot-html-viewer-label-oHPR4aFarS4rssRjGuJGoS" for="ipyplot-html-viewer-toggle-oHPR4aFarS4rssRjGuJGoS">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-oHPR4aFarS4rssRjGuJGoS" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-mix4b33cFTeFxGLjZkzzV7 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-mix4b33cFTeFxGLjZkzzV7 {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7 {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7 img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-mix4b33cFTeFxGLjZkzzV7">
#     <div class="ipyplot-placeholder-div-mix4b33cFTeFxGLjZkzzV7">
#         <div id="ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7-GokBu2y37LWEhSMxxyC2gU" class="ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">CVC-ClinicDB/PNG/Original/569.png</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7-GokBu2y37LWEhSMxxyC2gU">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mix4b33cFTeFxGLjZkzzV7">
#         <div id="ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7-Ubw2H3yH6NBfDwFek9FdE4" class="ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">CVC-ClinicDB/PNG/Original/103.png</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7-Ubw2H3yH6NBfDwFek9FdE4">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mix4b33cFTeFxGLjZkzzV7">
#         <div id="ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7-7a2YwJC8gaNphk46RmeUCf" class="ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">CVC-ClinicDB/PNG/Original/530.png</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7-7a2YwJC8gaNphk46RmeUCf">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mix4b33cFTeFxGLjZkzzV7">
#         <div id="ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7-aYhQBXjHQWEmV4utmFBEGv" class="ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">CVC-ClinicDB/PNG/Original/363.png</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7-aYhQBXjHQWEmV4utmFBEGv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mix4b33cFTeFxGLjZkzzV7">
#         <div id="ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7-Huqj2pbAVmFXXCQWzfxcQ6" class="ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">CVC-ClinicDB/PNG/Original/26.png</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7-Huqj2pbAVmFXXCQWzfxcQ6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mix4b33cFTeFxGLjZkzzV7">
#         <div id="ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7-Tx6zakZNsa74hThGXubkC3" class="ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">CVC-ClinicDB/PNG/Original/518.png</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="i
#         <style>
#         #ipyplot-imgs-container-div-mix4b33cFTeFxGLjZkzzV7 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-mix4b33cFTeFxGLjZkzzV7 {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7 {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7 img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-mix4b33cFTeFxGLjZkzzV7">
#     <div class="ipyplot-placeholder-div-mix4b33cFTeFxGLjZkzzV7">
#         <div id="ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7-GokBu2y37LWEhSMxxyC2gU" class="ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">CVC-ClinicDB/PNG/Original/569.png</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7-GokBu2y37LWEhSMxxyC2gU">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mix4b33cFTeFxGLjZkzzV7">
#         <div id="ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7-Ubw2H3yH6NBfDwFek9FdE4" class="ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">CVC-ClinicDB/PNG/Original/103.png</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7-Ubw2H3yH6NBfDwFek9FdE4">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mix4b33cFTeFxGLjZkzzV7">
#         <div id="ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7-7a2YwJC8gaNphk46RmeUCf" class="ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">CVC-ClinicDB/PNG/Original/530.png</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7-7a2YwJC8gaNphk46RmeUCf">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mix4b33cFTeFxGLjZkzzV7">
#         <div id="ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7-aYhQBXjHQWEmV4utmFBEGv" class="ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">CVC-ClinicDB/PNG/Original/363.png</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7-aYhQBXjHQWEmV4utmFBEGv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mix4b33cFTeFxGLjZkzzV7">
#         <div id="ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7-Huqj2pbAVmFXXCQWzfxcQ6" class="ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">CVC-ClinicDB/PNG/Original/26.png</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7-Huqj2pbAVmFXXCQWzfxcQ6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mix4b33cFTeFxGLjZkzzV7">
#         <div id="ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7-Tx6zakZNsa74hThGXubkC3" class="ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">CVC-ClinicDB/PNG/Original/518.png</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7-Tx6zakZNsa74hThGXubkC3">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-mix4b33cFTeFxGLjZkzzV7">
#         <div id="ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7-fUXwzyBdHjV9SDayG5cLpT" class="ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">CVC-ClinicDB/PNG/Original/273.png</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-mix4b33cFTeFxGLjZkzzV7-fUXwzyBdHjV9SDayG5cLpT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#     <style>
#         #ipyplot-html-viewer-toggle-4bXUeo9E2uY8WM9bNXm5aF {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-4bXUeo9E2uY8WM9bNXm5aF {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-4bXUeo9E2uY8WM9bNXm5aF {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-4bXUeo9E2uY8WM9bNXm5aF:checked ~ #ipyplot-html-viewer-textarea-4bXUeo9E2uY8WM9bNXm5aF {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-4bXUeo9E2uY8WM9bNXm5aF:checked + #ipyplot-html-viewer-label-4bXUeo9E2uY8WM9bNXm5aF:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-4bXUeo9E2uY8WM9bNXm5aF">
#         <label id="ipyplot-html-viewer-label-4bXUeo9E2uY8WM9bNXm5aF" for="ipyplot-html-viewer-toggle-4bXUeo9E2uY8WM9bNXm5aF">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-4bXUeo9E2uY8WM9bNXm5aF" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-WuKWiHq3zUqgUiD5PkS8Wu {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-WuKWiHq3zUqgUiD5PkS8Wu {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-WuKWiHq3zUqgUiD5PkS8Wu">
#     <div class="ipyplot-placeholder-div-WuKWiHq3zUqgUiD5PkS8Wu">
#         <div id="ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu-V3838LDSEpVYLGCARdmLUz" class="ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">CVC-ClinicDB/PNG/Ground Truth/569.png</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu-V3838LDSEpVYLGCARdmLUz">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WuKWiHq3zUqgUiD5PkS8Wu">
#         <div id="ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu-3WgZQWvoLhovbEBpDFqLkG" class="ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">CVC-ClinicDB/PNG/Ground Truth/103.png</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu-3WgZQWvoLhovbEBpDFqLkG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WuKWiHq3zUqgUiD5PkS8Wu">
#         <div id="ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu-iiR6SfJ8RgBNzce8RkGw3B" class="ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">CVC-ClinicDB/PNG/Ground Truth/530.png</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu-iiR6SfJ8RgBNzce8RkGw3B">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WuKWiHq3zUqgUiD5PkS8Wu">
#         <div id="ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu-jRbv2NAGnotJF4AQjvFqco" class="ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">CVC-ClinicDB/PNG/Ground Truth/363.png</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu-jRbv2NAGnotJF4AQjvFqco">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WuKWiHq3zUqgUiD5PkS8Wu">
#         <div id="ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu-QsVttVB2qWDSAvTqcJA2BZ" class="ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">CVC-ClinicDB/PNG/Ground Truth/26.png</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu-QsVttVB2qWDSAvTqcJA2BZ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WuKWiHq3zUqgUiD5PkS8Wu">
#         <div id="ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu-LXKzA3EytFqBZoMi7zLzi6" class="ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">CVC-ClinicDB/PNG/Ground Truth/518.png</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#         <style>
#         #ipyplot-imgs-container-div-WuKWiHq3zUqgUiD5PkS8Wu {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-WuKWiHq3zUqgUiD5PkS8Wu {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-WuKWiHq3zUqgUiD5PkS8Wu">
#     <div class="ipyplot-placeholder-div-WuKWiHq3zUqgUiD5PkS8Wu">
#         <div id="ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu-V3838LDSEpVYLGCARdmLUz" class="ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">CVC-ClinicDB/PNG/Ground Truth/569.png</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu-V3838LDSEpVYLGCARdmLUz">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WuKWiHq3zUqgUiD5PkS8Wu">
#         <div id="ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu-3WgZQWvoLhovbEBpDFqLkG" class="ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">CVC-ClinicDB/PNG/Ground Truth/103.png</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu-3WgZQWvoLhovbEBpDFqLkG">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WuKWiHq3zUqgUiD5PkS8Wu">
#         <div id="ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu-iiR6SfJ8RgBNzce8RkGw3B" class="ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">CVC-ClinicDB/PNG/Ground Truth/530.png</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu-iiR6SfJ8RgBNzce8RkGw3B">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WuKWiHq3zUqgUiD5PkS8Wu">
#         <div id="ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu-jRbv2NAGnotJF4AQjvFqco" class="ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">CVC-ClinicDB/PNG/Ground Truth/363.png</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu-jRbv2NAGnotJF4AQjvFqco">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WuKWiHq3zUqgUiD5PkS8Wu">
#         <div id="ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu-QsVttVB2qWDSAvTqcJA2BZ" class="ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">CVC-ClinicDB/PNG/Ground Truth/26.png</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu-QsVttVB2qWDSAvTqcJA2BZ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WuKWiHq3zUqgUiD5PkS8Wu">
#         <div id="ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu-LXKzA3EytFqBZoMi7zLzi6" class="ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">CVC-ClinicDB/PNG/Ground Truth/518.png</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu-LXKzA3EytFqBZoMi7zLzi6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-WuKWiHq3zUqgUiD5PkS8Wu">
#         <div id="ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu-5HrNVBFAahbJARU8DxVxfV" class="ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">CVC-ClinicDB/PNG/Ground Truth/273.png</h4><img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-WuKWiHq3zUqgUiD5PkS8Wu-5HrNVBFAahbJARU8DxVxfV">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %% [markdown]
# ## 3.5 Augmentations

# %%
def augment_data(images, masks, W, H, save_path, augment=True):
    """ Performing data augmentation. """
    #W = 384
    #H = 288
    crop_size = (H-32, W-32)
    size = (W, H)

    for image, mask in tqdm(zip(images, masks), total=len(images)):
        image_name = image.split("/")[-1].split(".")[0]
        mask_name = mask.split("/")[-1].split(".")[0]

        x, y = read_data(image, mask)
        try:
            h, w, c = x.shape
        except Exception as e:
            image = image[:-1]
            x, y = read_data(image, mask)
            h, w, c = x.shape

        if augment == True:
            ## Center Crop
            aug = CenterCrop(p=1, height=crop_size[0], width=crop_size[1])
            augmented = aug(image=x, mask=y)
            x1 = augmented['image']
            y1 = augmented['mask']

            ## Crop
            x_min = 0
            y_min = 0
            x_max = x_min + size[0]
            y_max = y_min + size[1]

            aug = Crop(p=1, x_min=x_min, x_max=x_max, y_min=y_min, y_max=y_max)
            augmented = aug(image=x, mask=y)
            x2 = augmented['image']
            y2 = augmented['mask']

            ## Random Rotate 90 degree
            aug = RandomRotate90(p=1)
            augmented = aug(image=x, mask=y)
            x3 = augmented['image']
            y3 = augmented['mask']

            ## Transpose
            aug = Transpose(p=1)
            augmented = aug(image=x, mask=y)
            x4 = augmented['image']
            y4 = augmented['mask']

            ## ElasticTransform
            aug = ElasticTransform(p=1, alpha=120, sigma=120 * 0.05, alpha_affine=120 * 0.03)
            augmented = aug(image=x, mask=y)
            x5 = augmented['image']
            y5 = augmented['mask']

            ## Grid Distortion
            aug = GridDistortion(p=1)
            augmented = aug(image=x, mask=y)
            x6 = augmented['image']
            y6 = augmented['mask']

            ## Optical Distortion
            aug = OpticalDistortion(p=1, distort_limit=2, shift_limit=0.5)
            augmented = aug(image=x, mask=y)
            x7 = augmented['image']
            y7 = augmented['mask']

            ## Vertical Flip
            aug = VerticalFlip(p=1)
            augmented = aug(image=x, mask=y)
            x8 = augmented['image']
            y8 = augmented['mask']

            ## Horizontal Flip
            aug = HorizontalFlip(p=1)
            augmented = aug(image=x, mask=y)
            x9 = augmented['image']
            y9 = augmented['mask']

            ## Grayscale
            x10 = cv2.cvtColor(x, cv2.COLOR_RGB2GRAY)
            y10 = y

            ## Grayscale Vertical Flip
            aug = VerticalFlip(p=1)
            augmented = aug(image=x10, mask=y10)
            x11 = augmented['image']
            y11 = augmented['mask']

            ## Grayscale Horizontal Flip
            aug = HorizontalFlip(p=1)
            augmented = aug(image=x10, mask=y10)
            x12 = augmented['image']
            y12 = augmented['mask']

            ## Grayscale Center Crop
            aug = CenterCrop(p=1, height=crop_size[0], width=crop_size[1])
            augmented = aug(image=x10, mask=y10)
            x13 = augmented['image']
            y13 = augmented['mask']

            ##
            aug = RandomBrightnessContrast(p=1)
            augmented = aug(image=x, mask=y)
            x14 = augmented['image']
            y14 = augmented['mask']

            aug = RandomGamma(p=1)
            augmented = aug(image=x, mask=y)
            x15 = augmented['image']
            y15 = augmented['mask']

            aug = HueSaturationValue(p=1)
            augmented = aug(image=x, mask=y)
            x16 = augmented['image']
            y16 = augmented['mask']

            aug = RGBShift(p=1)
            augmented = aug(image=x, mask=y)
            x17 = augmented['image']
            y17 = augmented['mask']

            aug = RandomBrightness(p=1)
            augmented = aug(image=x, mask=y)
            x18 = augmented['image']
            y18 = augmented['mask']

            aug = RandomContrast(p=1)
            augmented = aug(image=x, mask=y)
            x19 = augmented['image']
            y19 = augmented['mask']

            aug = MotionBlur(p=1, blur_limit=7)
            augmented = aug(image=x, mask=y)
            x20 = augmented['image']
            y20 = augmented['mask']

            aug = MedianBlur(p=1, blur_limit=9)
            augmented = aug(image=x, mask=y)
            x21 = augmented['image']
            y21 = augmented['mask']

            aug = GaussianBlur(p=1, blur_limit=9)
            augmented = aug(image=x, mask=y)
            x22 = augmented['image']
            y22 = augmented['mask']

            aug = GaussNoise(p=1)
            augmented = aug(image=x, mask=y)
            x23 = augmented['image']
            y23 = augmented['mask']

            aug = ChannelShuffle(p=1)
            augmented = aug(image=x, mask=y)
            x24 = augmented['image']
            y24 = augmented['mask']

            aug = CoarseDropout(p=1, max_holes=8, max_height=32, max_width=32)
            augmented = aug(image=x, mask=y)
            x25 = augmented['image']
            y25 = augmented['mask']

            images = [
                x, x1, x2, x3, x4, x5, x6, x7, x8, x9, x10,
                x11, x12, x13, x14, x15, x16, x17, x18, x19, x20,
                x21, x22, x23, x24, x25
            ]
            masks  = [
                y, y1, y2, y3, y4, y5, y6, y7, y8, y9, y10,
                y11, y12, y13, y14, y15, y16, y17, y18, y19, y20,
                y21, y22, y23, y24, y25
            ]

        else:
            images = [x]
            masks  = [y]

        idx = 0
        for i, m in zip(images, masks):
            i = cv2.resize(i, size)
            m = cv2.resize(m, size)

            tmp_image_name = f"{image_name}_{idx}.jpg"
            tmp_mask_name  = f"{mask_name}_{idx}.jpg"

            image_path = os.path.join(save_path, "image/", tmp_image_name)
            mask_path  = os.path.join(save_path, "mask/", tmp_mask_name)

            cv2.imwrite(image_path, i)
            cv2.imwrite(mask_path, m)

            idx += 1

# %% [markdown]
# ## 3.6 Save aug. data

# %% [markdown]
# Create directories to save augmentations later on

# %%
if config['first_time_data_arrangement']:
  create_dir("/content/CVC-ClinicDB/new_data/train/image/")
  create_dir("/content/CVC-ClinicDB/new_data/train/mask/")
  create_dir("/content/CVC-ClinicDB/new_data/valid/image/")
  create_dir("/content/CVC-ClinicDB/new_data/valid/mask/")
  create_dir("/content/CVC-ClinicDB/new_data/test/image/")
  create_dir("/content/CVC-ClinicDB/new_data/test/mask/")

# %% [markdown]
# Use augmentations

# %%
if config['first_time_data_arrangement']:
  W, H = [config['input_w'], config['input_h']] #size to resize if needed after augmentations
  augment_data(CVC_train_images_path, CVC_train_masks_path, W, H, "/content/CVC-ClinicDB/new_data/train/", augment=True)
  augment_data(CVC_valid_images_path, CVC_valid_masks_path, W, H, "/content/CVC-ClinicDB/new_data/valid/", augment=False)
  augment_data(CVC_test_images_path, CVC_test_masks_path, W, H, "/content/CVC-ClinicDB/new_data/test/", augment=False)
# Out:
#   0%|          | 0/490 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/albumentations/augmentations/transforms.py:1615: FutureWarning: This class has been deprecated. Please use RandomBrightnessContrast
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/albumentations/augmentations/transforms.py:1641: FutureWarning: RandomContrast has been deprecated. Please use RandomBrightnessContrast
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/albumentations/augmentations/transforms.py:1766: UserWarning: blur_limit and sigma_limit minimum value can not be both equal to 0. blur_limit minimum value changed to 3.
#   "blur_limit and sigma_limit minimum value can not be both equal to 0. "
# 100%|██████████| 490/490 [01:28<00:00,  5.56it/s]
# 100%|██████████| 61/61 [00:00<00:00, 132.32it/s]
# 100%|██████████| 61/61 [00:00<00:00, 129.79it/s]

# %% [markdown]
# ### 3.6.1 Save aug data as ZIP file

# %%
if config['first_time_data_arrangement']: a=1 # if it is "a" first time a will be 1
elif not config['first_time_data_arrangement']: a=0 #not a first time "a" will be 0
#using shell commend to zip only if it is a first time.
# !if [ $a -eq 1 ]; then zip -r /content/gdrive/MyDrive/CVC-ClinicDB-new_data.zip /content/CVC-ClinicDB/new_data; fi
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/CVC-ClinicDB/new_data/train/mask/319_16.jpg (deflated 49%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/179_0.jpg (deflated 46%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/353_6.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/140_15.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/475_0.jpg (deflated 22%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/288_16.jpg (deflated 45%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/150_20.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/581_21.jpg (deflated 29%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/327_25.jpg (deflated 44%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/55_5.jpg (deflated 59%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/553_16.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/268_7.jpg (deflated 20%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/560_24.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/487_3.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/488_8.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/507_9.jpg (deflated 24%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/253_20.jpg (deflated 24%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/210_17.jpg (deflated 21%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/372_11.jpg (deflated 55%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/420_23.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/89_24.jpg (deflated 42%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/153_20.jpg (deflated 38%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/454_5.jpg (deflated 34%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/484_12.jpg (deflated 29%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/528_20.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/10_25.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/316_4.jpg (deflated 25%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/173_5.jpg (deflated 30%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/31_24.jpg (deflated 35%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/492_19.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/470_16.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/608_13.jpg (deflated 46%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/188_12.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/559_18.jpg (deflated 66%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/535_6.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/304_21.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/9_5.jpg (deflated 20%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/116_19.jpg (deflated 25%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/521_1.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/244_23.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/555_4.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/508_5.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/62_14.jpg (deflated 52%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/77_13.jpg (deflated 41%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/565_15.jpg (deflated 32%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/286_17.jpg (deflated 46%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/42_15.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/90_3.jpg (deflated 40%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/363_3.jpg (deflated 49%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/153_5.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/190_14.jpg (deflated 43%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/392_9.jpg (deflated 34%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/509_8.jpg (deflated 30%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/553_24.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/390_13.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/245_12.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/114_22.jpg (deflated 25%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/165_23.jpg (deflated 35%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/35_20.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/203_8.jpg (deflated 42%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/402_11.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/60_13.jpg (deflated 45%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/560_18.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/153_10.jpg (deflated 38%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/343_23.jpg (deflated 41%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/405_5.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/339_4.jpg (deflated 46%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/245_14.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/446_0.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/68_5.jpg (deflated 32%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/316_13.jpg (deflated 25%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/340_1.jpg (deflated 51%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/300_9.jpg (deflated 35%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/458_9.jpg (deflated 40%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/278_19.jpg (deflated 48%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/458_23.jpg (deflated 40%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/71_16.jpg (deflated 51%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/8_2.jpg (deflated 24%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/589_10.jpg (deflated 48%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/54_11.jpg (deflated 62%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/485_8.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/236_14.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/108_14.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/405_4.jpg (deflated 35%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/253_5.jpg (deflated 20%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/97_15.jpg (deflated 40%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/394_9.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/468_10.jpg (deflated 26%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/245_7.jpg (deflated 30%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/43_17.jpg (deflated 39%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/565_4.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/446_4.jpg (deflated 32%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/58_4.jpg (deflated 55%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/155_22.jpg (deflated 48%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/134_8.jpg (deflated 40%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/388_22.jpg (deflated 22%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/216_15.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/61_17.jpg (deflated 48%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/322_12.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/273_18.jpg (deflated 22%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/126_17.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/114_16.jpg (deflated 25%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/429_10.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/184_10.jpg (deflated 46%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/317_4.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/87_13.jpg (deflated 35%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/493_9.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/60_16.jpg (deflated 47%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/466_5.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/169_5.jpg (deflated 34%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/144_7.jpg (deflated 32%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/212_21.jpg (deflated 21%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/252_18.jpg (deflated 32%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/226_2.jpg (deflated 40%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/563_12.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/461_14.jpg (deflated 38%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/287_7.jpg (deflated 23%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/381_11.jpg (deflated 48%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/189_24.jpg (deflated 39%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/606_7.jpg (deflated 18%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/509_11.jpg (deflated 30%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/394_2.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/86_11.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/263_13.jpg (deflated 30%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/471_20.jpg (deflated 22%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/49_3.jpg (deflated 35%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/46_5.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/80_8.jpg (deflated 54%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/124_20.jpg (deflated 24%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/297_22.jpg (deflated 46%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/531_7.jpg (deflated 39%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/87_23.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/84_7.jpg (deflated 41%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/162_13.jpg (deflated 38%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/500_22.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/69_4.jpg (deflated 54%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/42_11.jpg (deflated 38%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/280_24.jpg (deflated 44%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/346_24.jpg (deflated 44%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/401_24.jpg (deflated 32%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/276_24.jpg (deflated 25%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/63_11.jpg (deflated 52%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/384_16.jpg (deflated 22%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/371_6.jpg (deflated 54%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/542_22.jpg (deflated 39%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/59_23.jpg (deflated 53%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/199_17.jpg (deflated 43%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/225_8.jpg (deflated 42%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/56_20.jpg (deflated 46%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/342_14.jpg (deflated 34%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/437_22.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/188_7.jpg (deflated 17%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/279_0.jpg (deflated 47%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/148_6.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/342_9.jpg (deflated 35%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/535_20.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/329_8.jpg (deflated 41%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/502_23.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/97_6.jpg (deflated 42%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/599_22.jpg (deflated 45%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/402_19.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/125_18.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/259_12.jpg (deflated 24%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/122_7.jpg (deflated 24%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/148_4.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/512_2.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/121_13.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/242_24.jpg (deflated 29%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/121_4.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/540_23.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/303_22.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/304_2.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/230_19.jpg (deflated 25%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/291_13.jpg (deflated 50%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/50_0.jpg (deflated 45%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/462_5.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/528_3.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/387_19.jpg (deflated 22%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/500_11.jpg (deflated 30%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/296_23.jpg (deflated 46%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/16_15.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/524_19.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/523_16.jpg (deflated 40%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/259_8.jpg (deflated 24%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/368_5.jpg (deflated 46%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/367_19.jpg (deflated 48%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/420_8.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/201_7.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/267_4.jpg (deflated 23%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/215_17.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/476_21.jpg (deflated 21%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/548_20.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/155_21.jpg (deflated 48%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/103_8.jpg (deflated 34%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/153_7.jpg (deflated 21%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/210_6.jpg (deflated 20%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/468_2.jpg (deflated 26%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/611_16.jpg (deflated 43%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/74_14.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/511_13.jpg (deflated 35%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/197_21.jpg (deflated 42%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/45_19.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/320_2.jpg (deflated 44%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/322_0.jpg (deflated 38%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/500_21.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/61_16.jpg (deflated 48%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/462_10.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/9_22.jpg (deflated 26%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/608_18.jpg (deflated 48%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/316_9.jpg (deflated 25%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/258_22.jpg (deflated 25%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/227_11.jpg (deflated 42%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/595_3.jpg (deflated 45%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/15_18.jpg (deflated 26%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/549_11.jpg (deflated 40%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/587_12.jpg (deflated 48%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/531_12.jpg (deflated 46%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/116_25.jpg (deflated 25%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/496_15.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/42_16.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/90_20.jpg (deflated 40%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/442_5.jpg (deflated 38%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/72_24.jpg (deflated 38%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/115_18.jpg (deflated 23%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/336_3.jpg (deflated 40%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/35_15.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/128_1.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/342_3.jpg (deflated 34%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/113_0.jpg (deflated 25%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/139_15.jpg (deflated 29%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/362_24.jpg (deflated 34%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/14_5.jpg (deflated 20%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/58_15.jpg (deflated 52%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/496_0.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/89_2.jpg (deflated 42%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/452_20.jpg (deflated 44%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/513_14.jpg (deflated 35%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/89_18.jpg (deflated 42%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/336_18.jpg (deflated 40%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/492_7.jpg (deflated 21%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/276_1.jpg (deflated 24%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/351_20.jpg (deflated 39%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/182_20.jpg (deflated 43%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/452_1.jpg (deflated 42%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/84_15.jpg (deflated 41%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/270_17.jpg (deflated 24%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/412_5.jpg (deflated 35%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/298_6.jpg (deflated 35%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/61_7.jpg (deflated 49%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/254_17.jpg (deflated 24%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/90_24.jpg (deflated 40%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/178_18.jpg (deflated 63%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/500_4.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/51_14.jpg (deflated 54%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/600_9.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/212_4.jpg (deflated 21%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/49_12.jpg (deflated 34%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/490_10.jpg (deflated 21%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/395_15.jpg (deflated 32%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/508_18.jpg (deflated 30%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/125_13.jpg (deflated 30%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/197_16.jpg (deflated 42%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/490_0.jpg (deflated 21%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/526_18.jpg (deflated 35%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/466_16.jpg (deflated 32%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/494_19.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/498_8.jpg (deflated 25%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/493_20.jpg (deflated 26%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/54_7.jpg (deflated 58%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/393_14.jpg (deflated 34%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/174_11.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/35_23.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/91_25.jpg (deflated 41%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/589_8.jpg (deflated 48%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/178_19.jpg (deflated 63%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/242_0.jpg (deflated 29%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/156_11.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/196_24.jpg (deflated 43%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/112_4.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/574_12.jpg (deflated 46%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/181_22.jpg (deflated 47%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/293_4.jpg (deflated 46%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/509_19.jpg (deflated 29%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/319_22.jpg (deflated 49%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/376_23.jpg (deflated 48%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/280_3.jpg (deflated 44%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/358_18.jpg (deflated 34%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/236_23.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/164_18.jpg (deflated 43%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/603_15.jpg (deflated 35%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/441_6.jpg (deflated 42%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/268_12.jpg (deflated 23%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/491_24.jpg (deflated 26%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/582_5.jpg (deflated 32%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/184_1.jpg (deflated 43%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/173_13.jpg (deflated 30%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/109_7.jpg (deflated 26%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/559_20.jpg (deflated 66%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/490_11.jpg (deflated 21%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/188_19.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/55_7.jpg (deflated 82%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/207_4.jpg (deflated 25%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/107_4.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/323_13.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/310_17.jpg (deflated 45%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/147_24.jpg (deflated 32%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/266_10.jpg (deflated 22%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/386_24.jpg (deflated 22%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/263_3.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/411_4.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/506_16.jpg (deflated 26%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/319_21.jpg (deflated 49%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/198_16.jpg (deflated 43%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/566_25.jpg (deflated 39%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/165_21.jpg (deflated 35%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/193_11.jpg (deflated 48%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/312_19.jpg (deflated 54%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/24_2.jpg (deflated 30%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/105_3.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/104_9.jpg (deflated 30%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/494_11.jpg (deflated 32%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/50_7.jpg (deflated 46%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/562_16.jpg (deflated 30%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/531_6.jpg (deflated 48%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/56_25.jpg (deflated 46%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/280_0.jpg (deflated 44%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/115_5.jpg (deflated 20%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/393_22.jpg (deflated 34%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/227_14.jpg (deflated 42%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/7_25.jpg (deflated 25%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/607_6.jpg (deflated 50%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/586_6.jpg (deflated 38%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/16_1.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/82_3.jpg (deflated 47%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/358_20.jpg (deflated 34%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/475_1.jpg (deflated 20%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/327_10.jpg (deflated 44%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/189_1.jpg (deflated 40%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/549_15.jpg (deflated 41%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/436_17.jpg (deflated 38%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/239_23.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/398_16.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/488_18.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/440_24.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/422_0.jpg (deflated 23%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/305_18.jpg (deflated 29%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/3_5.jpg (deflated 20%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/32_11.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/72_11.jpg (deflated 38%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/458_11.jpg (deflated 40%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/539_1.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/336_6.jpg (deflated 40%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/78_23.jpg (deflated 50%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/210_3.jpg (deflated 21%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/375_18.jpg (deflated 55%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/233_16.jpg (deflated 29%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/485_18.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/482_2.jpg (deflated 26%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/485_24.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/598_23.jpg (deflated 45%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/224_3.jpg (deflated 46%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/154_19.jpg (deflated 58%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/581_4.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/125_17.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/394_19.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/398_20.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/271_7.jpg (deflated 17%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/246_20.jpg (deflated 32%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/89_11.jpg (deflated 41%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/12_15.jpg (deflated 22%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/54_24.jpg (deflated 62%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/300_18.jpg (deflated 35%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/35_13.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/396_8.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/548_22.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/551_12.jpg (deflated 32%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/119_14.jpg (deflated 24%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/555_24.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/479_3.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/12_18.jpg (deflated 22%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/311_19.jpg (deflated 44%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/581_16.jpg (deflated 29%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/158_10.jpg (deflated 39%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/213_21.jpg (deflated 23%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/581_22.jpg (deflated 29%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/258_4.jpg (deflated 23%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/204_1.jpg (deflated 44%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/68_25.jpg (deflated 35%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/335_10.jpg (deflated 40%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/388_10.jpg (deflated 22%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/278_16.jpg (deflated 48%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/546_17.jpg (deflated 38%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/93_4.jpg (deflated 44%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/356_6.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/40_16.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/176_25.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/525_15.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/89_23.jpg (deflated 42%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/179_21.jpg (deflated 46%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/245_1.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/217_1.jpg (deflated 30%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/480_11.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/209_20.jpg (deflated 38%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/439_12.jpg (deflated 38%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/441_23.jpg (deflated 49%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/12_8.jpg (deflated 23%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/238_23.jpg (deflated 26%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/509_1.jpg (deflated 30%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/180_25.jpg (deflated 44%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/330_6.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/190_13.jpg (deflated 42%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/461_24.jpg (deflated 38%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/531_21.jpg (deflated 46%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/130_4.jpg (deflated 34%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/219_10.jpg (deflated 32%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/575_3.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/398_9.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/336_10.jpg (deflated 40%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/254_15.jpg (deflated 24%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/307_9.jpg (deflated 32%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/112_19.jpg (deflated 24%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/480_0.jpg (deflated 29%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/154_25.jpg (deflated 58%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/62_25.jpg (deflated 52%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/312_14.jpg (deflated 54%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/222_11.jpg (deflated 42%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/446_23.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/508_21.jpg (deflated 30%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/1_21.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/24_21.jpg (deflated 30%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/161_17.jpg (deflated 44%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/578_0.jpg (deflated 38%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/356_5.jpg (deflated 26%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/523_5.jpg (deflated 39%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/55_9.jpg (deflated 56%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/394_12.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/524_5.jpg (deflated 24%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/340_11.jpg (deflated 52%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/590_2.jpg (deflated 48%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/428_23.jpg (deflated 41%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/4_7.jpg (deflated 18%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/487_20.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/85_9.jpg (deflated 39%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/538_16.jpg (deflated 41%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/27_11.jpg (deflated 50%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/532_13.jpg (deflated 42%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/551_10.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/117_20.jpg (deflated 24%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/402_13.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/229_2.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/81_20.jpg (deflated 34%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/83_25.jpg (deflated 35%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/488_16.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/15_11.jpg (deflated 26%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/32_19.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/440_17.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/263_19.jpg (deflated 29%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/43_7.jpg (deflated 40%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/212_0.jpg (deflated 21%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/154_5.jpg (deflated 54%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/319_15.jpg (deflated 49%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/438_25.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/45_21.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/491_8.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/533_18.jpg (deflated 42%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/218_21.jpg (deflated 32%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/578_15.jpg (deflated 38%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/182_9.jpg (deflated 43%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/285_19.jpg (deflated 44%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/231_6.jpg (deflated 26%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/512_8.jpg (deflated 38%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/294_21.jpg (deflated 43%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/4_12.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/151_10.jpg (deflated 39%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/140_17.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/438_10.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/578_24.jpg (deflated 38%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/368_24.jpg (deflated 47%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/560_17.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/217_20.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/207_17.jpg (deflated 26%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/561_6.jpg (deflated 35%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/482_5.jpg (deflated 24%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/32_21.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/594_16.jpg (deflated 43%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/168_6.jpg (deflated 38%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/290_22.jpg (deflated 52%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/581_9.jpg (deflated 29%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/2_3.jpg (deflated 29%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/574_4.jpg (deflated 47%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/297_2.jpg (deflated 46%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/82_20.jpg (deflated 44%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/415_13.jpg (deflated 26%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/178_24.jpg (deflated 63%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/261_9.jpg (deflated 24%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/6_17.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/438_21.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/448_7.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/13_6.jpg (deflated 32%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/401_14.jpg (deflated 32%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/304_25.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/587_7.jpg (deflated 48%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/288_10.jpg (deflated 45%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/14_6.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/112_18.jpg (deflated 24%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/181_14.jpg (deflated 47%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/292_20.jpg (deflated 50%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/382_16.jpg (deflated 44%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/108_11.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/242_11.jpg (deflated 30%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/523_0.jpg (deflated 40%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/113_8.jpg (deflated 25%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/353_16.jpg (deflated 35%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/161_3.jpg (deflated 45%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/245_25.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/461_5.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/213_19.jpg (deflated 23%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/40_3.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/484_9.jpg (deflated 29%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/544_15.jpg (deflated 30%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/154_7.jpg (deflated 59%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/518_18.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/119_11.jpg (deflated 24%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/18_16.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/401_17.jpg (deflated 32%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/524_6.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/506_0.jpg (deflated 26%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/92_20.jpg (deflated 42%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/351_23.jpg (deflated 39%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/269_17.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/549_24.jpg (deflated 41%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/10_18.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/310_15.jpg (deflated 45%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/239_25.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/452_6.jpg (deflated 41%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/383_8.jpg (deflated 48%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/421_11.jpg (deflated 29%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/179_4.jpg (deflated 47%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/271_11.jpg (deflated 25%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/415_10.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/90_13.jpg (deflated 39%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/162_9.jpg (deflated 40%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/611_1.jpg (deflated 42%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/340_20.jpg (deflated 52%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/93_8.jpg (deflated 42%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/468_25.jpg (deflated 26%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/547_3.jpg (deflated 35%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/163_6.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/311_3.jpg (deflated 44%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/370_20.jpg (deflated 54%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/468_21.jpg (deflated 26%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/524_24.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/232_15.jpg (deflated 29%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/589_9.jpg (deflated 48%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/42_20.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/70_16.jpg (deflated 38%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/172_7.jpg (deflated 52%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/547_24.jpg (deflated 35%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/176_21.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/293_22.jpg (deflated 43%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/169_0.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/570_20.jpg (deflated 40%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/531_10.jpg (deflated 46%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/495_23.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/389_12.jpg (deflated 25%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/529_15.jpg (deflated 47%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/428_20.jpg (deflated 41%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/303_21.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/41_2.jpg (deflated 41%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/339_7.jpg (deflated 43%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/185_22.jpg (deflated 43%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/312_21.jpg (deflated 54%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/578_12.jpg (deflated 39%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/139_14.jpg (deflated 29%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/287_22.jpg (deflated 43%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/348_5.jpg (deflated 21%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/546_13.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/198_25.jpg (deflated 43%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/128_20.jpg (deflated 39%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/171_23.jpg (deflated 38%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/201_3.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/236_1.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/122_25.jpg (deflated 26%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/409_12.jpg (deflated 30%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/592_21.jpg (deflated 41%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/114_7.jpg (deflated 26%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/575_5.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/261_20.jpg (deflated 25%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/522_23.jpg (deflated 38%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/461_23.jpg (deflated 38%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/13_25.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/122_6.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/340_21.jpg (deflated 52%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/7_21.jpg (deflated 25%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/256_1.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/13_8.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/580_3.jpg (deflated 30%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/156_1.jpg (deflated 38%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/399_2.jpg (deflated 30%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/494_4.jpg (deflated 30%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/576_7.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/204_5.jpg (deflated 43%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/3_3.jpg (deflated 30%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/302_25.jpg (deflated 32%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/82_8.jpg (deflated 44%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/240_4.jpg (deflated 29%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/429_0.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/173_22.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/186_23.jpg (deflated 35%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/289_16.jpg (deflated 45%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/522_0.jpg (deflated 38%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/305_24.jpg (deflated 29%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/30_19.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/276_2.jpg (deflated 25%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/235_14.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/555_11.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/66_2.jpg (deflated 53%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/18_15.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/402_10.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/258_6.jpg (deflated 22%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/4_13.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/126_14.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/424_6.jpg (deflated 46%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/24_6.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/296_1.jpg (deflated 45%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/456_22.jpg (deflated 34%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/31_6.jpg (deflated 35%)
# ...
#   adding: content/CVC-ClinicDB/new_data/train/mask/141_8.jpg (deflated 25%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/582_24.jpg (deflated 34%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/610_25.jpg (deflated 41%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/554_20.jpg (deflated 30%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/71_2.jpg (deflated 51%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/360_10.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/304_0.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/79_17.jpg (deflated 50%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/489_20.jpg (deflated 22%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/397_6.jpg (deflated 29%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/55_0.jpg (deflated 56%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/165_9.jpg (deflated 34%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/495_14.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/98_12.jpg (deflated 34%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/99_18.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/314_11.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/379_20.jpg (deflated 56%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/185_14.jpg (deflated 43%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/551_14.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/497_16.jpg (deflated 22%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/3_10.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/456_15.jpg (deflated 34%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/509_10.jpg (deflated 29%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/238_8.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/24_0.jpg (deflated 30%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/201_16.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/8_16.jpg (deflated 24%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/312_18.jpg (deflated 54%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/472_10.jpg (deflated 21%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/228_10.jpg (deflated 34%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/233_15.jpg (deflated 29%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/215_3.jpg (deflated 35%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/178_0.jpg (deflated 63%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/169_17.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/196_23.jpg (deflated 43%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/582_4.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/500_20.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/513_12.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/398_25.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/224_6.jpg (deflated 44%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/201_2.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/396_16.jpg (deflated 32%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/436_19.jpg (deflated 38%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/443_5.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/115_25.jpg (deflated 23%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/72_5.jpg (deflated 32%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/13_5.jpg (deflated 24%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/214_21.jpg (deflated 25%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/335_2.jpg (deflated 40%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/454_10.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/502_3.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/30_20.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/521_13.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/176_0.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/548_16.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/452_11.jpg (deflated 44%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/589_14.jpg (deflated 48%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/213_18.jpg (deflated 23%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/180_15.jpg (deflated 44%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/135_7.jpg (deflated 36%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/599_21.jpg (deflated 45%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/575_6.jpg (deflated 34%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/161_4.jpg (deflated 45%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/294_4.jpg (deflated 44%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/57_13.jpg (deflated 53%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/535_14.jpg (deflated 37%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/360_20.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/141_20.jpg (deflated 24%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/586_1.jpg (deflated 41%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/46_17.jpg (deflated 39%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/453_21.jpg (deflated 44%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/251_19.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/379_1.jpg (deflated 56%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/583_20.jpg (deflated 41%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/569_12.jpg (deflated 40%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/606_18.jpg (deflated 40%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/219_17.jpg (deflated 32%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/7_2.jpg (deflated 25%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/549_14.jpg (deflated 41%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/551_11.jpg (deflated 32%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/161_10.jpg (deflated 44%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/104_3.jpg (deflated 30%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/327_11.jpg (deflated 44%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/304_4.jpg (deflated 32%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/304_1.jpg (deflated 30%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/530_7.jpg (deflated 42%)
#   adding: content/CVC-ClinicDB/new_data/train/mask/471_7.jpg (deflated 17%)
#   adding: content/CVC-ClinicDB/new_data/test/ (stored 0%)
#   adding: content/CVC-ClinicDB/new_data/test/image/ (stored 0%)
#   adding: content/CVC-ClinicDB/new_data/test/image/449_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/64_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/515_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/431_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/36_0.jpg (deflated 2%)
#   adding: content/CVC-ClinicDB/new_data/test/image/223_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/39_0.jpg (deflated 2%)
#   adding: content/CVC-ClinicDB/new_data/test/image/118_0.jpg (deflated 2%)
#   adding: content/CVC-ClinicDB/new_data/test/image/324_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/558_0.jpg (deflated 2%)
#   adding: content/CVC-ClinicDB/new_data/test/image/44_0.jpg (deflated 2%)
#   adding: content/CVC-ClinicDB/new_data/test/image/160_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/65_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/106_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/167_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/391_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/577_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/23_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/191_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/200_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/22_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/282_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/364_0.jpg (deflated 2%)
#   adding: content/CVC-ClinicDB/new_data/test/image/67_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/206_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/75_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/457_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/510_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/331_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/143_0.jpg (deflated 2%)
#   adding: content/CVC-ClinicDB/new_data/test/image/503_0.jpg (deflated 2%)
#   adding: content/CVC-ClinicDB/new_data/test/image/5_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/465_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/152_0.jpg (deflated 2%)
#   adding: content/CVC-ClinicDB/new_data/test/image/425_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/138_0.jpg (deflated 2%)
#   adding: content/CVC-ClinicDB/new_data/test/image/591_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/265_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/157_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/262_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/170_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/593_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/250_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/295_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/132_0.jpg (deflated 2%)
#   adding: content/CVC-ClinicDB/new_data/test/image/504_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/467_0.jpg (deflated 2%)
#   adding: content/CVC-ClinicDB/new_data/test/image/514_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/406_0.jpg (deflated 2%)
#   adding: content/CVC-ClinicDB/new_data/test/image/527_0.jpg (deflated 2%)
#   adding: content/CVC-ClinicDB/new_data/test/image/414_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/337_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/159_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/423_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/474_0.jpg (deflated 2%)
#   adding: content/CVC-ClinicDB/new_data/test/image/596_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/142_0.jpg (deflated 2%)
#   adding: content/CVC-ClinicDB/new_data/test/image/464_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/38_0.jpg (deflated 2%)
#   adding: content/CVC-ClinicDB/new_data/test/image/309_0.jpg (deflated 1%)
#   adding: content/CVC-ClinicDB/new_data/test/image/95_0.jpg (deflated 2%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/ (stored 0%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/449_0.jpg (deflated 41%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/64_0.jpg (deflated 54%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/515_0.jpg (deflated 35%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/431_0.jpg (deflated 38%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/36_0.jpg (deflated 42%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/223_0.jpg (deflated 42%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/39_0.jpg (deflated 45%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/118_0.jpg (deflated 22%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/324_0.jpg (deflated 38%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/558_0.jpg (deflated 34%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/44_0.jpg (deflated 34%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/160_0.jpg (deflated 34%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/65_0.jpg (deflated 55%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/106_0.jpg (deflated 25%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/167_0.jpg (deflated 43%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/391_0.jpg (deflated 39%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/577_0.jpg (deflated 30%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/23_0.jpg (deflated 30%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/191_0.jpg (deflated 57%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/200_0.jpg (deflated 39%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/22_0.jpg (deflated 17%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/282_0.jpg (deflated 44%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/364_0.jpg (deflated 49%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/67_0.jpg (deflated 49%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/206_0.jpg (deflated 25%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/75_0.jpg (deflated 35%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/457_0.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/510_0.jpg (deflated 32%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/331_0.jpg (deflated 38%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/143_0.jpg (deflated 42%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/503_0.jpg (deflated 25%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/5_0.jpg (deflated 26%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/465_0.jpg (deflated 33%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/152_0.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/425_0.jpg (deflated 47%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/138_0.jpg (deflated 30%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/591_0.jpg (deflated 49%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/265_0.jpg (deflated 23%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/157_0.jpg (deflated 35%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/262_0.jpg (deflated 26%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/170_0.jpg (deflated 42%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/593_0.jpg (deflated 39%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/250_0.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/295_0.jpg (deflated 45%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/132_0.jpg (deflated 41%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/504_0.jpg (deflated 35%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/467_0.jpg (deflated 27%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/514_0.jpg (deflated 31%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/406_0.jpg (deflated 34%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/527_0.jpg (deflated 39%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/414_0.jpg (deflated 25%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/337_0.jpg (deflated 39%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/159_0.jpg (deflated 49%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/423_0.jpg (deflated 28%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/474_0.jpg (deflated 25%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/596_0.jpg (deflated 48%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/142_0.jpg (deflated 26%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/464_0.jpg (deflated 34%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/38_0.jpg (deflated 45%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/309_0.jpg (deflated 40%)
#   adding: content/CVC-ClinicDB/new_data/test/mask/95_0.jpg (deflated 41%)

# %% [markdown]
# ## 3.7 Dataset class

# %% [markdown]
# define Dataset class

# %%
class CvcClinicDbDataset(Dataset):
    def __init__(self, CVC_images_folder, CVC_masks_folder, transform = None):
        '''define self parameters, root folders to read from images and masks '''
        self.CVC_images_folder = CVC_images_folder
        self.CVC_masks_folder = CVC_masks_folder
        self.transform = transform
        # get to self parameters images and masks path lists for when we want to get item from dataset
        self.CVC_images_path, self.CVC_masks_path = load_data(self.CVC_images_folder, self.CVC_masks_folder)

    def __getitem__(self, index):
        CVC_image_path = self.CVC_images_path[index]
        CVC_mask_path = self.CVC_masks_path[index]
        
        CVC_image = cv2.imread(CVC_image_path, cv2.IMREAD_COLOR).astype(np.float32)/255.0 #need to read them as float for NN
        CVC_mask = cv2.imread(CVC_mask_path, cv2.IMREAD_GRAYSCALE).astype(np.float32)/255.0 #need to read them as float for NN

        sample = {'image': CVC_image, 'mask': CVC_mask}
        if self.transform:
            #print("in transform!")
            sample = self.transform(sample)
        return sample


    def __len__(self):
        return len(self.CVC_images_path)

    def load_data(images_folder_path, masks_folder_path):
        '''load the data to 2 path lists for images and masks.'''

        images = [images_folder_path+name for name in os.listdir(images_folder_path)]
        masks = [masks_folder_path+name for name in os.listdir(masks_folder_path)]
        return images, masks

# %%
class ToTensor(object):
    """Convert ndarrays in sample to Tensors."""

    def __call__(self, sample):
        image, mask = sample['image'], sample['mask']

        # swap color axis because
        # numpy image: H x W x C
        # torch image: C X H X W
        image = image.transpose((2, 0, 1))
        mask = np.expand_dims(mask, axis=-1)
        mask = mask.transpose((2, 0, 1))
        #print(image)
        return {'image': torch.from_numpy(image),
                'mask': torch.from_numpy(mask)}

# %% [markdown]
# ## 3.8 DataLoaders for train and validation

# %% [markdown]
# Load dataset class

# %%
CVC_clinic_DB_train = CvcClinicDbDataset("/content/CVC-ClinicDB-new_data/content/CVC-ClinicDB/new_data/train/image/", "/content/CVC-ClinicDB-new_data/content/CVC-ClinicDB/new_data/train/mask/",transform = ToTensor())

# %%
train_dataloader = DataLoader(CVC_clinic_DB_train, batch_size=config['batch_size'],
                        shuffle=True, num_workers= config['num_workers'])

# %%
CVC_clinic_DB_valid = CvcClinicDbDataset("/content/CVC-ClinicDB-new_data/content/CVC-ClinicDB/new_data/valid/image/", "/content/CVC-ClinicDB-new_data/content/CVC-ClinicDB/new_data/valid/mask/",transform = ToTensor())

# %%
valid_dataloader = DataLoader(CVC_clinic_DB_valid, batch_size=config['batch_size'],
                        shuffle=True, num_workers=config['num_workers'])

# %%
CVC_clinic_DB_test = CvcClinicDbDataset("/content/CVC-ClinicDB-new_data/content/CVC-ClinicDB/new_data/test/image/", "/content/CVC-ClinicDB-new_data/content/CVC-ClinicDB/new_data/test/mask/",transform = ToTensor())

# %%
test_dataloader = DataLoader(CVC_clinic_DB_test, batch_size=config['batch_size'],
                        shuffle=True, num_workers=config['num_workers'])

# %% [markdown]
# # 4 Data science bowl 2018

# %% [markdown]
# ## 4.1 Utils for this dataset

# %%
def load_data(images_folder_path, masks_folder_path):
  '''load the data to 2 path lists for images and masks.'''

  images = [images_folder_path+name for name in os.listdir(images_folder_path)]
  masks = [masks_folder_path+name for name in os.listdir(masks_folder_path)]
  return images, masks

def read_data_to_list(path_of_the_directory,path_to_save):
  """ Read the image and mask from the given images and masks lists of paths. """
  create_dir(path_to_save+ "image/")
  create_dir(path_to_save+ "mask/")
  images = []
  masks = []

  for filename in tqdm(os.listdir(path_of_the_directory)):
    f = os.path.join(path_of_the_directory,filename)
    bowl_image_path, bowl_masks_path = load_data(f + "/images/", f + "/masks/")

    # Getting the image:
    images.append(cv2.imread(bowl_image_path[0], cv2.IMREAD_COLOR))

    # Getting the mask:
    for i,mask in enumerate(bowl_masks_path):
      tmp_mask = cv2.imread(mask, cv2.IMREAD_COLOR)
      if i==0:
        final_mask = tmp_mask
      else:
        final_mask = cv2.bitwise_or(final_mask, tmp_mask)
    masks.append(final_mask)   

    # Save images & masks:
    image_path = os.path.join(path_to_save, "image/", filename +'.jpg')
    mask_path  = os.path.join(path_to_save, "mask/", filename + '.jpg')

    cv2.imwrite(image_path, images[-1])
    cv2.imwrite(mask_path, masks[-1])

  return images, masks

def split_data(images,masks):
  ''' split the data to 80-10-10'''
  train_size=int(0.8*len(images))
  valid_size=int(0.1*len(images))
  test_size=int(0.1*len(images))
  
  train_x, test_x = train_test_split(images, test_size=test_size, random_state=42)
  train_y, test_y = train_test_split(masks, test_size=test_size, random_state=42)

  train_x, valid_x = train_test_split(train_x, test_size=valid_size, random_state=42)
  train_y, valid_y = train_test_split(train_y, test_size=valid_size, random_state=42)

  return (train_x, train_y), (valid_x, valid_y), (test_x, test_y) 

def read_data(x, y):
    """ Read the image and mask from the given path. """
    image = cv2.imread(x, cv2.IMREAD_COLOR)
    mask = cv2.imread(y, cv2.IMREAD_COLOR)
    return image, mask

# %% [markdown]
# ## 4.2 Load the data:

# %%
if config['first_time_data_arrangement']:
  path_of_the_directory = '/content/bowl_dataset/stage1_train'
  path_to_save = '/content/bowl_dataset/'

  bowl_images, bowl_masks = read_data_to_list(path_of_the_directory,path_to_save)

  print("\n\nNumbers of images for bowl dataset: " + str(len(bowl_images)))
  print("Numbers of masks for bowl dataset: " + str(len(bowl_masks)))

# %% [markdown]
# ## 4.3 Split the data:

# %%
if config['first_time_data_arrangement']:
  # Get images & masks paths:
  bowl_images_path, bowl_masks_path = load_data("/content/bowl_dataset/image/", "/content/bowl_dataset/mask/")

  (bowl_train_images_path, bowl_train_masks_path), (bowl_valid_images_path, bowl_valid_masks_path), (bowl_test_images_path, bowl_test_masks_path) = split_data(bowl_images_path,bowl_masks_path)
  print("Numbers of bowl_train_images: " + str(len(bowl_train_images_path)))
  print("Numbers of bowl_valid_images: " + str(len(bowl_valid_images_path)))
  print("Numbers of bowl_test_images: " + str(len(bowl_test_images_path)))
  print("Numbers of bowl_train_masks: " + str(len(bowl_train_masks_path)))
  print("Numbers of bowl_valid_masks: " + str(len(bowl_valid_masks_path)))
  print("Numbers of bowl_test_masks: " + str(len(bowl_test_masks_path)))

# %% [markdown]
# ## 4.4 Data examples:

# %%
if config['first_time_data_arrangement']:
  ipyplot.plot_images(bowl_images, max_images=7, img_width=150, force_b64=True)
  ipyplot.plot_images(bowl_masks, max_images=7, img_width=150, force_b64=True)

# %% [markdown]
# ## 4.5 Augmentations:

# %%
def augment_data(images, masks, W, H, save_path, augment=True):
    """ Performing data augmentation. """
    #W = 384
    #H = 288
    crop_size = (H-32, W-32)
    size = (W, H)

    for image, mask in tqdm(zip(images, masks), total=len(images)):
        image_name = image.split("/")[-1].split(".")[0]
        mask_name = mask.split("/")[-1].split(".")[0]

        x, y = read_data(image, mask)
        try:
            h, w, c = x.shape
        except Exception as e:
            image = image[:-1]
            x, y = read_data(image, mask)
            h, w, c = x.shape

        if augment == True:
            ## Center Crop
            aug = CenterCrop(p=1, height=crop_size[0], width=crop_size[1])
            augmented = aug(image=x, mask=y)
            x1 = augmented['image']
            y1 = augmented['mask']

            ## Crop
            x_min = 0
            y_min = 0
            x_max = x_min + size[0]
            y_max = y_min + size[1]

            aug = Crop(p=1, x_min=x_min, x_max=x_max, y_min=y_min, y_max=y_max)
            augmented = aug(image=x, mask=y)
            x2 = augmented['image']
            y2 = augmented['mask']

            ## Random Rotate 90 degree
            aug = RandomRotate90(p=1)
            augmented = aug(image=x, mask=y)
            x3 = augmented['image']
            y3 = augmented['mask']

            ## Transpose
            aug = Transpose(p=1)
            augmented = aug(image=x, mask=y)
            x4 = augmented['image']
            y4 = augmented['mask']

            ## ElasticTransform
            aug = ElasticTransform(p=1, alpha=120, sigma=120 * 0.05, alpha_affine=120 * 0.03)
            augmented = aug(image=x, mask=y)
            x5 = augmented['image']
            y5 = augmented['mask']

            ## Grid Distortion
            aug = GridDistortion(p=1)
            augmented = aug(image=x, mask=y)
            x6 = augmented['image']
            y6 = augmented['mask']

            ## Optical Distortion
            aug = OpticalDistortion(p=1, distort_limit=2, shift_limit=0.5)
            augmented = aug(image=x, mask=y)
            x7 = augmented['image']
            y7 = augmented['mask']

            ## Vertical Flip
            aug = VerticalFlip(p=1)
            augmented = aug(image=x, mask=y)
            x8 = augmented['image']
            y8 = augmented['mask']

            ## Horizontal Flip
            aug = HorizontalFlip(p=1)
            augmented = aug(image=x, mask=y)
            x9 = augmented['image']
            y9 = augmented['mask']

            ## Grayscale
            x10 = cv2.cvtColor(x, cv2.COLOR_RGB2GRAY)
            y10 = y

            ## Grayscale Vertical Flip
            aug = VerticalFlip(p=1)
            augmented = aug(image=x10, mask=y10)
            x11 = augmented['image']
            y11 = augmented['mask']

            ## Grayscale Horizontal Flip
            aug = HorizontalFlip(p=1)
            augmented = aug(image=x10, mask=y10)
            x12 = augmented['image']
            y12 = augmented['mask']

            ## Grayscale Center Crop
            aug = CenterCrop(p=1, height=crop_size[0], width=crop_size[1])
            augmented = aug(image=x10, mask=y10)
            x13 = augmented['image']
            y13 = augmented['mask']

            ##
            aug = RandomBrightnessContrast(p=1)
            augmented = aug(image=x, mask=y)
            x14 = augmented['image']
            y14 = augmented['mask']

            aug = RandomGamma(p=1)
            augmented = aug(image=x, mask=y)
            x15 = augmented['image']
            y15 = augmented['mask']

            aug = HueSaturationValue(p=1)
            augmented = aug(image=x, mask=y)
            x16 = augmented['image']
            y16 = augmented['mask']

            aug = RGBShift(p=1)
            augmented = aug(image=x, mask=y)
            x17 = augmented['image']
            y17 = augmented['mask']

            aug = RandomBrightness(p=1)
            augmented = aug(image=x, mask=y)
            x18 = augmented['image']
            y18 = augmented['mask']

            aug = RandomContrast(p=1)
            augmented = aug(image=x, mask=y)
            x19 = augmented['image']
            y19 = augmented['mask']

            aug = MotionBlur(p=1, blur_limit=7)
            augmented = aug(image=x, mask=y)
            x20 = augmented['image']
            y20 = augmented['mask']

            aug = MedianBlur(p=1, blur_limit=9)
            augmented = aug(image=x, mask=y)
            x21 = augmented['image']
            y21 = augmented['mask']

            aug = GaussianBlur(p=1, blur_limit=9)
            augmented = aug(image=x, mask=y)
            x22 = augmented['image']
            y22 = augmented['mask']

            aug = GaussNoise(p=1)
            augmented = aug(image=x, mask=y)
            x23 = augmented['image']
            y23 = augmented['mask']

            aug = ChannelShuffle(p=1)
            augmented = aug(image=x, mask=y)
            x24 = augmented['image']
            y24 = augmented['mask']

            aug = CoarseDropout(p=1, max_holes=8, max_height=32, max_width=32)
            augmented = aug(image=x, mask=y)
            x25 = augmented['image']
            y25 = augmented['mask']

            images = [
                x, x1, x2, x3, x4, x5, x6, x7, x8, x9, x10,
                x11, x12, x13, x14, x15, x16, x17, x18, x19, x20,
                x21, x22, x23, x24, x25
            ]
            masks  = [
                y, y1, y2, y3, y4, y5, y6, y7, y8, y9, y10,
                y11, y12, y13, y14, y15, y16, y17, y18, y19, y20,
                y21, y22, y23, y24, y25
            ]

        else:
            images = [x]
            masks  = [y]

        idx = 0
        for i, m in zip(images, masks):
            i = cv2.resize(i, size)
            m = cv2.resize(m, size)

            tmp_image_name = f"{image_name}_{idx}.jpg"
            tmp_mask_name  = f"{mask_name}_{idx}.jpg"

            image_path = os.path.join(save_path, "image/", tmp_image_name)
            mask_path  = os.path.join(save_path, "mask/", tmp_mask_name)

            cv2.imwrite(image_path, i)
            cv2.imwrite(mask_path, m)

            idx += 1

# %% [markdown]
# ## 4.6 Save aug. data

# %%
if config['first_time_data_arrangement']:

  create_dir("/content/bowl_dataset/new_data/train/image/")
  create_dir("/content/bowl_dataset/new_data/train/mask/")
  create_dir("/content/bowl_dataset/new_data/valid/image/")
  create_dir("/content/bowl_dataset/new_data/valid/mask/")
  create_dir("/content/bowl_dataset/new_data/test/image/")
  create_dir("/content/bowl_dataset/new_data/test/mask/")

# %%
if config['first_time_data_arrangement']:
  W, H = [config['input_w'], config['input_h']] #size to resize if needed after augmentations
  augment_data(bowl_train_images_path, bowl_train_masks_path, W, H, "/content/bowl_dataset/new_data/train/", augment=True)
  augment_data(bowl_valid_images_path, bowl_valid_masks_path, W, H, "/content/bowl_dataset/new_data/valid/", augment=False)
  augment_data(bowl_test_images_path, bowl_test_masks_path, W, H, "/content/bowl_dataset/new_data/test/", augment=False)

# %% [markdown]
# ### 4.6.1 Save aug data as ZIP file

# %%
#!zip -r  /content/gdrive/MyDrive/bowl_dataset-new_data.zip /content/bowl_dataset/new_data

# %%
if config['first_time_data_arrangement']: a=1 # if it is "a" first time a will be 1
elif not config['first_time_data_arrangement']: a=0 #not a first time "a" will be 0
#using shell commend to zip only if it is a first time.
# !if [ $a -eq 1 ]; then zip -r  /content/bowl_dataset-new_data.zip /content/bowl_dataset-new_data; fi

# %% [markdown]
# ## 4.7 Dataset class:

# %%
class BowlDataset(Dataset):
    def __init__(self, bowl_images_folder, bowl_masks_folder, transform = None):
        '''define self parameters, root folders to read from images and masks '''
        self.bowl_images_folder = bowl_images_folder
        self.bowl_masks_folder = bowl_masks_folder
        self.transform = transform
        # get to self parameters images and masks path lists for when we want to get item from dataset
        self.bowl_images_path, self.bowl_masks_path = load_data(self.bowl_images_folder, self.bowl_masks_folder)

    def __getitem__(self, index):
        bowl_image_path = self.bowl_images_path[index]
        bowl_mask_path = self.bowl_masks_path[index]
        
        bowl_image = cv2.imread(bowl_image_path, cv2.IMREAD_COLOR).astype(np.float32)/255.0 #need to read them as float for NN
        bowl_mask = cv2.imread(bowl_mask_path, cv2.IMREAD_GRAYSCALE).astype(np.float32)/255.0 #need to read them as float for NN

        sample = {'image': bowl_image, 'mask': bowl_mask}
        if self.transform:
            #print("in transform!")
            sample = self.transform(sample)
        return sample


    def __len__(self):
        return len(self.bowl_images_path)

    def load_data(images_folder_path, masks_folder_path):
        '''load the data to 2 path lists for images and masks.'''

        images = [images_folder_path+name for name in os.listdir(images_folder_path)]
        masks = [masks_folder_path+name for name in os.listdir(masks_folder_path)]
        return images, masks

# %%
class ToTensor(object):
    """Convert ndarrays in sample to Tensors."""

    def __call__(self, sample):
        image, mask = sample['image'], sample['mask']

        # swap color axis because
        # numpy image: H x W x C
        # torch image: C X H X W
        image = image.transpose((2, 0, 1))
        mask = np.expand_dims(mask, axis=-1)
        mask = mask.transpose((2, 0, 1))
        #print(image)
        return {'image': torch.from_numpy(image),
                'mask': torch.from_numpy(mask)}

# %% [markdown]
# ## 4.8 DataLoaders for train and validation

# %% [markdown]
# Load dataset class

# %%
bowl_train = BowlDataset("/content/bowl_dataset-new_data/content/bowl_dataset/new_data/train/image/", "/content/bowl_dataset-new_data/content/bowl_dataset/new_data/train/mask/",transform = ToTensor())

# %%
train_dataloader = DataLoader(bowl_train, batch_size=config['batch_size'],
                        shuffle=True, num_workers= config['num_workers'])

# %%
bowl_valid = BowlDataset("/content/bowl_dataset-new_data/content/bowl_dataset/new_data/valid/image/", "/content/bowl_dataset-new_data/content/bowl_dataset/new_data/valid/mask/",transform = ToTensor())

# %%
valid_dataloader = DataLoader(bowl_valid, batch_size=config['batch_size'],
                        shuffle=True, num_workers=config['num_workers'])

# %%
bowl_test = BowlDataset("/content/bowl_dataset-new_data/content/bowl_dataset/new_data/test/image/", "/content/bowl_dataset-new_data/content/bowl_dataset/new_data/test/mask/",transform = ToTensor())

# %%
test_dataloader = DataLoader(bowl_test, batch_size=config['batch_size'],
                        shuffle=True, num_workers=config['num_workers'])

# %% [markdown]
# # 5 Model Architecture

# %% [markdown]
# ## 5.1 conv block

# %%
class conv_block(nn.Module):
    def __init__(self, filters , input_channels):
        super().__init__()
        self.conv_layer1 = nn.Conv2d(input_channels, filters, 3, padding='same')
        self.BN_layer1 = nn.BatchNorm2d(filters)
        self.ReLu1 = nn.ReLU(inplace=True)

        self.conv_layer2 = nn.Conv2d(filters, filters, 3, padding='same')
        self.BN_layer2 = nn.BatchNorm2d(filters)
        self.ReLu2 = nn.ReLU(inplace=True)

        self.SE = SqueezeExcitation(input_channels = filters, squeeze_channels = filters//config['squeeze_ratio'])

    def forward(self, x):

         z = self.conv_layer1(x)
         z = self.BN_layer1(z)
         z = self.ReLu1(z)
         
         z = self.conv_layer2(z)
         z = self.BN_layer2(z)
         z = self.ReLu2(z)

         z = self.SE(z)

         return z

# %% [markdown]
# ## 5.2 encoder1

# %%
class encoder1(nn.Module):

    def __init__(self):
        super().__init__()
        self.VGG_19 = vgg19(pretrained= True, progress = True)
        #self.output_shape = self.VGG_19.features[35].register_forward_hook(output.detach())

    def forward(self, x):
        skip_connections = {}
        def get_activation(name):
            ''' function that stores layers outputs in dict named skip_connections '''
            def hook(model, input, output):
                skip_connections[name]=output.detach()
            return hook

        skip_connections_layer = [3,8,17,26,35] # Middle outputs of VGG. 
        for num,layer in enumerate(skip_connections_layer):
            self.VGG_19.features[layer].register_forward_hook(get_activation('ConvBlock'+str(num)))

        self.VGG_19(x)

        encoder1_output = skip_connections['ConvBlock4']
        del skip_connections['ConvBlock4']


        return  encoder1_output, skip_connections

# %% [markdown]
# ## 5.3 ASPP

# %%
class ASPP(nn.Module):

    ''' 512 is the channels of encoder1 output '''
    def __init__(self,shape,filter):
        super().__init__()
        self.AvgPool1 = nn.AvgPool2d(kernel_size=(shape[2], shape[3]))
        self.conv_layer1 = nn.Conv2d(shape[1], filter, kernel_size=1, padding=1)
        self.BN_layer1 = nn.BatchNorm2d(filter)
        self.ReLu1 = nn.ReLU(inplace=True)
        self.UpSampling = nn.Upsample((shape[2], shape[3]) , mode = 'bilinear')

        self.conv_layer2 = nn.Conv2d(shape[1], filter, kernel_size=1 , dilation=1, padding='same' , bias ="False")
        self.BN_layer2 = nn.BatchNorm2d(filter)
        self.ReLu2 = nn.ReLU(inplace=True)

        self.conv_layer3 = nn.Conv2d(shape[1], filter, kernel_size=3 , dilation=6, padding='same', bias ="False")
        self.BN_layer3 = nn.BatchNorm2d(filter)
        self.Relu3 = nn.ReLU(inplace=True)

        self.conv_layer4 = nn.Conv2d(shape[1], filter, kernel_size=3 , dilation=12, padding='same', bias ="False")
        self.BN_layer4 = nn.BatchNorm2d(filter)
        self.Relu4 = nn.ReLU(inplace=True)

        self.conv_layer5 = nn.Conv2d(shape[1], filter, kernel_size=3 , dilation=18, padding='same', bias ="False")
        self.BN_layer5  = nn.BatchNorm2d(filter)
        self.Relu5 = nn.ReLU(inplace=True)

        self.conv_layer6 = nn.Conv2d(filter*5, filter, kernel_size=1 , dilation=1, padding='same', bias ="False")
        self.BN_layer6 = nn.BatchNorm2d(filter)
        self.Relu6 = nn.ReLU(inplace=True)

    def forward(self, x):

        y1 = self.AvgPool1(x) ## SUS
        y1 = self.conv_layer1(y1)
        y1 = self.BN_layer1(y1)
        y1 = self.ReLu1(y1)
        y1 = self.UpSampling(y1)

        y2 = self.conv_layer2(x)
        y2 = self.BN_layer2(y2)
        y2 = self.ReLu2(y2)

        y3 = self.conv_layer3(x)
        y3 = self.BN_layer3(y3)
        y3 = self.Relu3(y3)

        y4 = self.conv_layer4(x)
        y4 = self.BN_layer4(y4)
        y4 = self.Relu4(y4)

        y5 = self.conv_layer5(x)
        y5 = self.BN_layer5(y5)
        y5 = self.Relu5(y5)

        y = torch.cat((y1,y2,y3,y4,y5),1)

        y = self.conv_layer6(y)
        y = self.BN_layer6(y)
        y = self.Relu6(y)        
        
        return y

# %% [markdown]
# ## 5.4 Attention block

# %%
class Attention_block(nn.Module):
    def __init__(self,F_g,F_l,F_int):
        super().__init__()
        self.W_g = nn.Sequential(
            nn.Conv2d(F_g, F_int, kernel_size=1,stride=1,padding=0,bias=True),
            nn.BatchNorm2d(F_int)
            )
        
        self.W_x = nn.Sequential(
            nn.Conv2d(F_l, F_int, kernel_size=1,stride=2,padding=0,bias=True),
            nn.BatchNorm2d(F_int)
        )

        self.psi = nn.Sequential(
            nn.Conv2d(F_int, 1, kernel_size=1,stride=1,padding=0,bias=True),
            nn.BatchNorm2d(1),
            nn.Sigmoid(),
            nn.Upsample(scale_factor = 2 , mode = 'bilinear')
        )
        
        self.relu = nn.ReLU(inplace=True)
        
    def forward(self,g,xt):
        g1 = self.W_g(g)
        x1 = self.W_x(xt)
        psi = self.relu(g1+x1)
        psi = self.psi(psi)

        return xt*psi

# %% [markdown]
# ## 5.5 decoder1

# %%
class decoder1(nn.Module):
    def __init__(self):
        super().__init__()

        self.ConvBlock1 = conv_block(filters = 256 , input_channels = 576)
        self.ConvBlock2 = conv_block(filters = 128 , input_channels = 512)
        self.ConvBlock3 = conv_block(filters = 64 , input_channels = 256)
        self.ConvBlock4 = conv_block(filters = 32 , input_channels = 128)

        self.UpSampling1 = nn.Upsample(scale_factor = 2 , mode = 'bilinear')
        self.UpSampling2 = nn.Upsample(scale_factor = 2 , mode = 'bilinear')
        self.UpSampling3 = nn.Upsample(scale_factor = 2 , mode = 'bilinear')
        self.UpSampling4 = nn.Upsample(scale_factor = 2 , mode = 'bilinear')

        self.Att1 = Attention_block(F_g=64,F_l=512,F_int=512)
        self.Att2 = Attention_block(F_g=256,F_l=256,F_int=256)
        self.Att3 = Attention_block(F_g=128,F_l=128,F_int=128)
        self.Att4 = Attention_block(F_g=64,F_l=64,F_int=64)

        

    def forward(self, x , skip_connections):
        #print(x.shape)
        #print(skip_connections['ConvBlock3'].shape)
        xt3 = self.Att1(g=x, xt=skip_connections['ConvBlock3']) 
        x = self.UpSampling1(x) ### SUS
        #xt3 = self.Att1(g=x, xt=skip_connections['ConvBlock3']) 
        x = torch.cat((x, xt3),1)
        x = self.ConvBlock1(x) ##

        xt2 = self.Att2(g=x, xt = skip_connections['ConvBlock2'] )
        x = self.UpSampling2(x) ### SUS
        #xt2 = self.Att2(g=x, xt = skip_connections['ConvBlock2'] )
        x = torch.cat((x, xt2),1)
        x = self.ConvBlock2(x)

        xt1 = self.Att3(g=x, xt = skip_connections['ConvBlock1'] )
        x = self.UpSampling3(x) ### SUS
        #xt1 = self.Att3(g=x, xt = skip_connections['ConvBlock1'] )
        x = torch.cat((x, xt1),1)
        x = self.ConvBlock3(x)

        xt0 = self.Att4(g=x, xt = skip_connections['ConvBlock0'] )
        x = self.UpSampling4(x) ### SUS
        #xt0 = self.Att4(g=x, xt = skip_connections['ConvBlock0'] )
        x = torch.cat((x, xt0),1)
        z = self.ConvBlock4(x)

        return z

# %% [markdown]
# ## 5.6 output block

# %%
class output_block(nn.Module):
    def __init__(self):
        super().__init__()

        self.conv_layer = nn.Conv2d(32,1,kernel_size=1, padding='same')
        self.sig = nn.Sigmoid()

    def forward(self, x):
        x = self.conv_layer(x)
        z = self.sig(x)

        return z

# %% [markdown]
# ## 5.7 encoder2

# %%
class encoder2(nn.Module):

    def __init__(self):
        super().__init__()

        self.ConvBlock1 = conv_block(filters = 32 , input_channels = 3)
        self.ConvBlock2 = conv_block(filters = 64 , input_channels = 32)
        self.ConvBlock3 = conv_block(filters = 128 , input_channels = 64)
        self.ConvBlock4 = conv_block(filters = 256 , input_channels = 128)

        self.MaxPooling1 = nn.MaxPool2d(kernel_size=2)
        self.MaxPooling2 = nn.MaxPool2d(kernel_size=2)
        self.MaxPooling3 = nn.MaxPool2d(kernel_size=2)
        self.MaxPooling4 = nn.MaxPool2d(kernel_size=2)

        self.drop1 = nn.Dropout(p=0.25, inplace = False)
        self.drop2 = nn.Dropout(p=0.5, inplace = False)
        self.drop3 = nn.Dropout(p=0.5, inplace = False)
        self.drop4 = nn.Dropout(p=0.5, inplace = False)

    def forward(self, x):
      # add dropout after pooling
        skip_connections = {}

        x = self.ConvBlock1(x)
        skip_connections['encoder2Block0']=x
        x = self.MaxPooling1(x)
        x = self.drop1(x)

        x = self.ConvBlock2(x)
        skip_connections['encoder2Block1']=x
        x = self.MaxPooling2(x)
        x = self.drop2(x)

        x = self.ConvBlock3(x)
        skip_connections['encoder2Block2']=x
        x = self.MaxPooling3(x)
        x = self.drop3(x)

        x = self.ConvBlock4(x)
        skip_connections['encoder2Block3']=x
        z = self.MaxPooling4(x)
        z = self.drop4(z)

        return  z, skip_connections

# %% [markdown]
# ## 5.8 decoder2

# %%
class decoder2(nn.Module):
    def __init__(self):
        super().__init__()

        self.ConvBlock1 = conv_block(filters = 256 , input_channels = 832)
        self.ConvBlock2 = conv_block(filters = 128 , input_channels = 640)
        self.ConvBlock3 = conv_block(filters = 64 , input_channels = 320)
        self.ConvBlock4 = conv_block(filters = 32 , input_channels = 160)

        self.UpSampling1 = nn.Upsample(scale_factor = 2 , mode = 'bilinear')
        self.UpSampling2 = nn.Upsample(scale_factor = 2 , mode = 'bilinear')
        self.UpSampling3 = nn.Upsample(scale_factor = 2 , mode = 'bilinear')
        self.UpSampling4 = nn.Upsample(scale_factor = 2 , mode = 'bilinear')
        
        self.Att1_enc1 = Attention_block(F_g=64,F_l=512,F_int=512)
        self.Att2_enc1 = Attention_block(F_g=256,F_l=256,F_int=256)
        self.Att3_enc1 = Attention_block(F_g=128,F_l=128,F_int=128)
        self.Att4_enc1 = Attention_block(F_g=64,F_l=64,F_int=64)

        self.Att1_enc2 = Attention_block(F_g=64,F_l=256,F_int=256)
        self.Att2_enc2 = Attention_block(F_g=256,F_l=128,F_int=128)
        self.Att3_enc2 = Attention_block(F_g=128,F_l=64,F_int=64)
        self.Att4_enc2 = Attention_block(F_g=64,F_l=32,F_int=32)

        self.drop1 = nn.Dropout(p=0.5, inplace = False)
        self.drop2 = nn.Dropout(p=0.5, inplace = False)
        self.drop3 = nn.Dropout(p=0.5, inplace = False)
        self.drop4 = nn.Dropout(p=0.5, inplace = False)


    def forward(self, x , skip_1, skip_2):
      #add drop out after concats
        
        xt3_enc1 = self.Att1_enc1(g=x, xt=skip_1['ConvBlock3']) 
        xt3_enc2 = self.Att1_enc2(g=x, xt=skip_2['encoder2Block3']) 
        x = self.UpSampling1(x) ### SUS
        #xt3_enc1 = self.Att1_enc1(g=x, xt=skip_1['ConvBlock3']) 
        #xt3_enc2 = self.Att1_enc2(g=x, xt=skip_2['encoder2Block3']) 
        x = torch.cat((x, xt3_enc1,xt3_enc2),1)
        x = self.drop1(x)
        x = self.ConvBlock1(x)

        xt2_enc1 = self.Att2_enc1(g=x, xt = skip_1['ConvBlock2'] )
        xt2_enc2 = self.Att2_enc2(g=x, xt=skip_2['encoder2Block2']) 
        x = self.UpSampling2(x) ### SUS
        #xt2_enc1 = self.Att2_enc1(g=x, xt = skip_1['ConvBlock2'] )
        #xt2_enc2 = self.Att2_enc2(g=x, xt=skip_2['encoder2Block2']) 
        x = torch.cat((x, xt2_enc1,xt2_enc2),1)
        x = self.drop2(x)
        x = self.ConvBlock2(x)

        xt1_enc1 = self.Att3_enc1(g=x, xt = skip_1['ConvBlock1'] )
        xt1_enc2 = self.Att3_enc2(g=x, xt=skip_2['encoder2Block1']) 
        x = self.UpSampling3(x) ### SUS
        #xt1_enc1 = self.Att3_enc1(g=x, xt = skip_1['ConvBlock1'] )
        #xt1_enc2 = self.Att3_enc2(g=x, xt=skip_2['encoder2Block1']) 
        x = torch.cat((x, xt1_enc1,xt1_enc2),1)
        x = self.drop3(x)
        x = self.ConvBlock3(x)

        xt0_enc1 = self.Att4_enc1(g=x, xt = skip_1['ConvBlock0'] )
        xt0_enc2 = self.Att4_enc2(g=x, xt=skip_2['encoder2Block0']) 
        x = self.UpSampling4(x) ### SUS
        #xt0_enc1 = self.Att4_enc1(g=x, xt = skip_1['ConvBlock0'] )
        #xt0_enc2 = self.Att4_enc2(g=x, xt=skip_2['encoder2Block0'])
        x = torch.cat((x, xt0_enc1,xt0_enc2),1)
        x = self.drop4(x)
        z = self.ConvBlock4(x)

        return z

# %% [markdown]
# ## 5.9 DoubleAU-Net Class

# %%
## removed the //2 at inputs sizes
## removed resized input at the begining and at the end

class DoubleUNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder1 = encoder1()

        if config['use_interpolation'] == False:
          self.ASPP1 = ASPP(shape = [config['batch_size'], 512, config['input_h']//16, config['input_w']//16] , filter = 64) ## dividing by 16 is because of x4 MaxPooiling in each encoder
        elif config['use_interpolation'] == True:  
          self.ASPP1 = ASPP(shape = [config['batch_size'], 512, config['input_h']//2//16, config['input_w']//2//16] , filter = 64) ## In case we want to use interpolation

        self.decoder1 = decoder1()
        self.outblock1 = output_block()
        self.encoder2 = encoder2()

        if config['use_interpolation'] == False:
          self.ASPP2 = ASPP(shape = [config['batch_size'], 256, config['input_h']//16, config['input_w']//16] , filter = 64) ## dividing by 16 is because of x4 MaxPooiling in each encoder
        elif config['use_interpolation'] == True:
          self.ASPP2 = ASPP(shape = [config['batch_size'], 256, config['input_h']//2//16, config['input_w']//2//16] , filter = 64) ## In case we want to use interpolation

        self.decoder2 = decoder2()
        self.outblock2 = output_block()
    
    def forward(self,input):
        if config['use_interpolation'] == False:
          resized_input = input
        elif config ['use_interpolation'] == True:
          resized_input = F.interpolate(input,(config['input_h']//2,config['input_w']//2)) # In case we want to use interpolation

        encoder1_output,skip_connections1 = self.encoder1(resized_input)
        y1 = self.ASPP1(encoder1_output)

        decoder1_output = self.decoder1(y1,skip_connections1)
        output1= self.outblock1(decoder1_output)

        mul = output1*resized_input

        encoder2_output, skip_connections2 = self.encoder2(mul)
        y2 = self.ASPP2 (encoder2_output)

        decoder2_output = self.decoder2(y2,skip_connections1,skip_connections2)

        output2= self.outblock2(decoder2_output)

        if config['use_interpolation'] == False:
          resized_output2 = output2
        elif config['use_interpolation'] == True:
          resized_output2 = F.interpolate(output2,(config['input_h'],config['input_w'])) # In case we want to use interpolation

        #print (output2.shape)
        return resized_output2

# %% [markdown]
# # 6 Metrics

# %%
# need to see if we want to do this method on 1 sample or batch of samples, if so no need for dim
def dice_coef(y_true, y_pred):
 
    y_true = nn.Flatten()(y_true) #flatten all dimensions for the model output except the first one (the batch dimention)
    y_pred = nn.Flatten()(y_pred) #flatten all dimensions for the groud truth except the first one (the batch dimention)
    #y_pred = torch.round(y_pred)

    intersection = torch.sum(y_true * y_pred,1) # we get (num of element in batch) answers, one for each true and pred in betch.
    return (2. * intersection + config['smooth']) / (torch.sum(y_true,1) + torch.sum(y_pred,1) + config['smooth'])


def dice_loss(y_true, y_pred):

    return 1.0 - dice_coef(y_true, y_pred)

def iou(y_true, y_pred):
    with torch.no_grad():
      y_true = nn.Flatten()(y_true) #flatten all dimensions for the model output except the first one (the batch dimention)
      y_pred = nn.Flatten()(y_pred) #flatten all dimensions for the groud truth except the first one (the batch dimention)
      y_pred = torch.round(y_pred)

      intersection = torch.sum(y_true * y_pred,1) # we get (num of element in batch) answers, one for each true and pred in betch.
      union = torch.sum(y_true,1) + torch.sum(y_pred,1) - intersection
      x = (intersection + config['smooth']) / (union + config['smooth'])
      #x = x.astype(np.float32)
      return x

def bce_dice_loss(y_true, y_pred):

    return F.binary_cross_entropy(y_pred, y_true) + dice_loss(y_true, y_pred)

def focal_loss(y_true, y_pred):
    alpha=0.25
    gamma=2

    def focal_loss_with_logits(logits, targets, alpha, gamma, y_pred):
        weight_a = alpha * (1 - y_pred) ** gamma * targets
        weight_b = (1 - alpha) * y_pred ** gamma * (1 - targets)
        return (torch.log(1+torch.exp(-torch.abs(logits))) + F.relu(-logits)) * (weight_a + weight_b) + logits * weight_b

    y_pred = torch.clamp(y_pred, 1e-07, 1 - 1e-07)
    logits = torch.log(y_pred / (1 - y_pred))
    loss = focal_loss_with_logits(logits=logits, targets=y_true, alpha=alpha, gamma=gamma, y_pred=y_pred)
    # or reduce_sum and/or axis=-1
    return loss - torch.mean(loss) 
    #return tf.reduce_mean(loss)

def calculate_prec_rec(y_true, y_pred):
    with torch.no_grad():
      y_true = nn.Flatten()(y_true) #flatten all dimensions for the model output except the first one (the batch dimention)
      y_pred = nn.Flatten()(y_pred) #flatten all dimensions for the groud truth except the first one (the batch dimention)

      #y_true = torch.round(y_true)
      y_pred = torch.round(y_pred)

      intersection = torch.sum(y_true * y_pred,1) # we get (num of element in batch) answers, one for each true and pred in betch.
      tp = torch.sum(y_pred * y_true,1)  # TP
      fp = torch.sum(y_pred *(1-y_true),1)  # FP
      fn = torch.sum(((1 - y_pred) * y_true),1)  # FN
      tn = torch.sum(((1 - y_pred) * (1 - y_true)),1)  # TN


      precision = (tp + config['smooth']) / (tp + fp + config['smooth'])
      recall = (tp + config['smooth']) / (tp + fn + config['smooth'])


      return  precision, recall

# %% [markdown]
# # 7 Training

# %% [markdown]
# ## 7.1 Test function

# %%
def test(model,valid_data,output_file_path):
    model.eval()
    valid_loss = 0
    mPrecision=0
    mRecall=0
    mIOU=0
    avg_batch_valid_DSC=0
    
    num_batches = len(valid_data)
    with torch.no_grad():
        for batch_idx,batch in enumerate(valid_data):
            # Getting the batch data:
            x = batch['image'].to(device) #GPU
            y = batch['mask'].to(device) # GPU

            # Getting predictions:
            y_pred = model(x)

            if config['dataset']=='CVC':
              batch_loss = bce_dice_loss(y,y_pred)
            elif config['dataset']=='bowl':
              batch_loss = dice_loss(y,y_pred)
              
            batch_valid_DSC = dice_coef(y,y_pred)

            #print(batch_loss)
            avg_batch_valid_DSC += batch_valid_DSC.sum()/(len(batch_valid_DSC))
            loss = batch_loss.sum()/(len(batch_loss))
            valid_loss+=loss #sums up all avg batch losses

            # Calculating Accuracy:
            precision, recall = calculate_prec_rec(y, y_pred)
            pred_iou = iou(y, y_pred)

            mPrecision+=precision.sum()/(len(precision)) #mean precision of a batch and sums them up
            mRecall+=recall.sum()/(len(recall)) #mean recall of a batch and sums them up
            mIOU+=pred_iou.sum()/(len(pred_iou)) #mean IOU of a batch and sums them up

    valid_loss /= num_batches
    valid_DSC = avg_batch_valid_DSC / num_batches
    print_both('\n~~~~~~~~~~~~~~~~~ Test Loss: {:.4f} ~~~~~~~~~~~~~~~~~\n'.format(valid_loss),output_file_path = output_file_path)
    print_both('mean Precision:{}   |    mean Recall:{}   |    mIOU:{}    |   DSC:{}\n'.format(mPrecision/ num_batches, mRecall/ num_batches, mIOU/ num_batches, valid_DSC),output_file_path = output_file_path)
    
    return valid_loss.item(), valid_DSC.item(), (mPrecision/ num_batches).item(), (mRecall/ num_batches).item(), (mIOU/ num_batches).item()

# %% [markdown]
# ## 7.2 Train function

# %%
def train(model,train_data ,valid_data,test_data,epochs = config['epochs']):

    # datetime object containing current date and time
    now = datetime.now()
    # dd/mm/YY H:M:S
    dt_string = now.strftime("%d.%m.%Y %H:%M:%S")
    create_dir(config['output_path']+str(dt_string))

    #optimizer:
    if config['dataset']=='CVC':
      opt = NAdam(params=model.parameters() ,lr=config['lr'],eps=config['eps'])
    elif config['dataset']=='bowl':
      opt = Adam(params=model.parameters() ,lr=config['lr'],eps=config['eps'])

    # scheduler:
    scheduler = lr_scheduler.ReduceLROnPlateau(opt, 'min', factor = config['scheduler_reduce_lr_factor'], patience = config['scheduler_patience'])
     #set model mode:
    model.train()

    # define variables:
    num_batches = len(train_data)

    output_file_path = config['output_path']+str(dt_string)+"/output.txt" #open file to save all prints to it

    print_both(model,output_file_path=output_file_path)
    print_both('\nTrain started at:{}\n'.format(dt_string),output_file_path=output_file_path)
    print_both('\Model architecture:{}\n'.format(config['notebook_name']),output_file_path=output_file_path)

    #save config to txt file
    dict_to_txt(dict_ = config , output_file_path = config['output_path']+str(dt_string)+'/config.txt')

    best_epoch_stats = {}
    train_loss_epoch_arr = []
    train_mPrecision_arr = []
    train_mRecall_arr = []
    train_mIOU_arr = []
    train_DSC_arr =[]

    valid_loss_epoch_arr = []
    valid_mPrecision_arr = []
    valid_mRecall_arr = []
    valid_mIOU_arr = []
    valid_DSC_arr=[]

    best_valid_loss = 100
    
    # Early stopping parameters
    last_loss = 100
    ES_patience = config['early_stopping_patience']
    triggertimes = 0

    print_both ('~~~~~~~~~~~ START OF TRAINING ~~~~~~~~~~~\n',output_file_path=output_file_path)

    #training loop:
    for epoch in range(epochs):
        print_both(' ---------Starting EPOCH {}---------\n '.format(epoch),output_file_path=output_file_path)
        train_loss=0
        mPrecision=0
        mRecall=0
        mIOU=0
        train_DSC=0
        model.train()

        if (epoch ==10):
          config["lr"] = 1e-5


        for batch_idx,batch in enumerate(train_data): 
            # Getting the batch data:
            x = batch['image'].to(device) #GPU
            y = batch['mask'].to(device) # GPU

            # Getting predictions:
            y_pred = model(x)
            #y_pred>0.5

            # Calculating loss:
            if config['dataset']=='CVC':
              batch_loss = bce_dice_loss(y,y_pred)
            elif config['dataset']=='bowl':
              batch_loss = dice_loss(y,y_pred)

              
            batch_train_DSC = dice_coef(y,y_pred)
            

            #print(batch_loss)
            train_DSC += batch_train_DSC.sum()/(len(batch_train_DSC))
            loss = batch_loss.sum()/(len(batch_loss)) #sum the batch losses and devide by the number of samples in batch, mean loss 
            train_loss+=loss.item()

            # Calculating Accuracy:
            precision, recall = calculate_prec_rec(y, y_pred) #tensors with size of batch, each element represent precision (and) recall for each image and prediction
            pred_iou = iou(y, y_pred) #tensor with size of batch, each element represent iou for each image and prediction
            
            mPrecision+=precision.sum()/(len(precision)) #mean precision of a batch and sums them up
            mRecall+=recall.sum()/(len(recall)) #mean recall of a batch and sums them up
            mIOU+=pred_iou.sum()/(len(pred_iou)) #mean IOU of a batch and sums them up

            # Back propagation:
            opt.zero_grad()
            loss.backward()
            opt.step()

            num_images_vs_batch = batch_idx * len(x) #batch number mult. number of images in a batch
            total_num_images = len(train_data)*len(x) #num of batches nult. num of umages in a batch
            batch_ratio = batch_idx/ len(train_data)
            # print every 100 batches
            if batch_idx % 100 == 0:
                print_both('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}\n'.format(epoch, num_images_vs_batch, total_num_images ,100. * batch_ratio, loss.item()),output_file_path=output_file_path)

        epoch_avg_loss = train_loss / num_batches  #take the total losses per batch and devide by the number of batches 
        epoch_avg_DSC = train_DSC.item() / num_batches

        train_mPrecision =   mPrecision.item()/ num_batches
        train_mRecall = mRecall.item()/ num_batches
        train_mIOU = mIOU.item()/ num_batches

        print_both('~~~~~~~~~~~ Epoch: {} Average loss: {:.4f} ~~~~~~~~~~~\n'.format(epoch, epoch_avg_loss),output_file_path=output_file_path)
        print_both('mean Precision:{}   |    mean Recall:{}   |    mIOU:{}    |   DSC:{}\n'.format(train_mPrecision, train_mRecall, train_mIOU, epoch_avg_DSC),output_file_path=output_file_path)

        end_time = datetime.now()
        # dd/mm/YY H:M:S
        end_time_dt = end_time.strftime("%d.%m.%Y %H:%M:%S")
        print_both('\nEpoch ended at:{}\n'.format(end_time_dt),output_file_path=output_file_path)

        # validation:
        valid_loss, valid_DSC, valid_mPrecision, valid_mRecall, valid_mIOU  = test(model,valid_data,output_file_path) 


        #save train and validation params vs epochs for plot later on
        train_loss_epoch_arr.append(epoch_avg_loss)
        save_list(train_loss_epoch_arr,output_path = config['output_path']+str(dt_string)+'/train_loss_arr.pkl')

        train_mPrecision_arr.append(train_mPrecision)
        save_list(train_mPrecision_arr,output_path = config['output_path']+str(dt_string)+'/train_mPrecision_arr.pkl')

        train_mRecall_arr.append(train_mRecall)
        save_list(train_mRecall_arr,output_path = config['output_path']+str(dt_string)+'/train_mRecall_arr.pkl')

        train_mIOU_arr.append(train_mIOU)
        save_list(train_mIOU_arr,output_path = config['output_path']+str(dt_string)+'/train_mIOU_arr.pkl')

        train_DSC_arr.append(epoch_avg_DSC)
        save_list(train_DSC_arr,output_path = config['output_path']+str(dt_string)+'/train_DSC_arr.pkl')

        valid_loss_epoch_arr.append(valid_loss)
        save_list(valid_loss_epoch_arr,output_path = config['output_path']+str(dt_string)+'/valid_loss_epoch_arr.pkl')

        valid_mPrecision_arr.append(valid_mPrecision)
        save_list(valid_mPrecision_arr,output_path = config['output_path']+str(dt_string)+'/valid_mPrecision_arr.pkl')

        valid_mRecall_arr.append(valid_mRecall)
        save_list(valid_mRecall_arr,output_path = config['output_path']+str(dt_string)+'/valid_mRecall_arr.pkl')

        valid_mIOU_arr.append(valid_mIOU)
        save_list(valid_mIOU_arr,output_path = config['output_path']+str(dt_string)+'/valid_mIOU_arr.pkl')

        valid_DSC_arr.append(valid_DSC)
        save_list(valid_DSC_arr,output_path = config['output_path']+str(dt_string)+'/valid_DSC_arr.pkl')


        torch.save (model.state_dict(),config['output_path']+str(dt_string)+'/DoubleUNet_last_checkpoint.pth')

        # saving model and stats to output folder:
        if (valid_loss<best_valid_loss):
          torch.save (model.state_dict(),config['output_path']+str(dt_string)+'/DoubleUNet.pth')
          best_valid_loss = valid_loss 
          best_epoch_stats = {'epoch': epoch,
                              'Train mPrecision': train_mPrecision ,
                              'Train mRecall': train_mRecall,
                              'Train mIOU': train_mIOU,
                              'Train loss': epoch_avg_loss,
                              'Train DSC' : epoch_avg_DSC,
                              'Valid mPrecision': valid_mPrecision ,
                              'Valid mRecall': valid_mRecall,
                              'Valid mIOU': valid_mIOU,
                              'Valid loss': valid_loss,
                              'Valid DSC' : valid_DSC,
                              }
          #write best_epoch_stats dict to txt file
          dict_to_txt(dict_ = best_epoch_stats , output_file_path = config['output_path']+str(dt_string)+'/best_epoch_stats.txt')
          
        
        # reduce lr plateau
        scheduler.step(valid_loss)

        # Early stopping
        current_loss = valid_loss

        if current_loss > last_loss:
            trigger_times += 1
            print_both('Early stopping Trigger Times:\n', trigger_times,output_file_path=output_file_path)

            if trigger_times >= ES_patience:
                print_both('Early stopping!\nStart to final test process.\n',output_file_path=output_file_path)
                return model

        else:
            print_both('trigger times: 0\n',output_file_path=output_file_path)
            trigger_times = 0

        last_loss = current_loss

    return model

# %% [markdown]
# ## 7.3 Train model

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
DoubleUNet_model = DoubleUNet().to(device)
#print(DoubleUNet_model)

train(DoubleUNet_model,train_dataloader,valid_dataloader,test_dataloader,epochs=config['epochs'])

# %% [markdown]
# # 8 Load metrices

# %%
folder_in_output = '10.10.2022 09:35:15/'

train_loss_arr = load_list(config['output_path']+folder_in_output+'train_loss_arr.pkl')
train_mPrecision_arr = load_list(config['output_path']+folder_in_output+'train_mPrecision_arr.pkl')
train_mRecall_arr = load_list(config['output_path']+folder_in_output+'train_mRecall_arr.pkl')
train_mIOU_arr = load_list(config['output_path']+folder_in_output+'train_mIOU_arr.pkl')
train_DSC_arr = load_list(config['output_path']+folder_in_output+'train_DSC_arr.pkl')
valid_loss_epoch_arr = load_list(config['output_path']+folder_in_output+'valid_loss_epoch_arr.pkl')
valid_mPrecision_arr = load_list(config['output_path']+folder_in_output+'valid_mPrecision_arr.pkl')
valid_mRecall_arr = load_list(config['output_path']+folder_in_output+'valid_mRecall_arr.pkl')
valid_mIOU_arr = load_list(config['output_path']+folder_in_output+'valid_mIOU_arr.pkl')
valid_DSC_arr = load_list(config['output_path']+folder_in_output+'valid_DSC_arr.pkl')

# %% [markdown]
# # 9 Plot metrices

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

fig, axs = plt.subplots(1, 5,)
fig.set_size_inches((26, 4))

#loss
i = 0
axs[i].plot (train_loss_arr , label = "Train" , marker='o')
axs[i].plot (valid_loss_epoch_arr , label = "Test" , marker='o')
axs[i].set_ylabel ('loss')
axs[i].set_title ('DoubleAU-Net loss')
axs[i].set_xlabel ('Epoch')

#mPrecision
i+=1
axs[i].plot (train_mPrecision_arr , label = "Train" , marker='o')
axs[i].plot (valid_mPrecision_arr , label = "Test" , marker='o')
axs[i].set_ylabel ('mPrecision')
axs[i].set_title ('DoubleAU-Net mPrecision')

#mRecall
i+=1
axs[i].plot (train_mRecall_arr , label = "Train" , marker='o')
axs[i].plot (valid_mRecall_arr , label = "Test" , marker='o')
axs[i].set_title ('DoubleAU-Net mRecall')
axs[i].set_ylabel ('mRecall')

#mIOU
i+=1
axs[i].plot (train_mIOU_arr , label = "Train" , marker='o')
axs[i].plot (valid_mIOU_arr , label = "Test" , marker='o')
axs[i].set_title ('DoubleAU-Net mIOU')
axs[i].set_ylabel ('mIOU')

#mDSC
i+=1
axs[i].plot (train_DSC_arr , label = "Train" , marker='o')
axs[i].plot (valid_DSC_arr , label = "Test" , marker='o')
axs[i].set_title ('DoubleAU-Net DSC')
axs[i].set_ylabel ('DSC')

for j in range(5):
  axs[j].set_xlabel ('Epoch')
  axs[j].xaxis.set_major_locator(MaxNLocator(integer=True))
  axs[j].legend()
  axs[j].grid()

# %% [markdown]
# # 10 Final model test

# %% [markdown]
# ## 10.1 Load model function

# %%
def load_model(model_path):
    #folder_in_output = '/09.09.2022 16:58:04/'
    device = "cuda" if torch.cuda.is_available() else "cpu"
    DoubleUNet_model = DoubleUNet().to(device)
    loaded_model = DoubleUNet_model
    loaded_model.eval()
    loaded_model.load_state_dict(torch.load(model_path,map_location=torch.device(device)))
    loaded_model.eval()
    return loaded_model

# %% [markdown]
# ## 10.2 Test function

# %%
def final_test(model,valid_data,output_file_path):
    model.eval()
    valid_loss = 0
    mPrecision=0
    mRecall=0
    mIOU=0
    avg_batch_valid_DSC=0
    
    num_batches = len(valid_data)
    with torch.no_grad():
        for batch_idx,batch in enumerate(valid_data):
            # Getting the batch data:
            x = batch['image'].to(device) #GPU
            y = batch['mask'].to(device) # GPU

            # Getting predictions:
            y_pred = model(x)
            
            if config['dataset']=='CVC':
              batch_loss = bce_dice_loss(y,y_pred)
            elif config['dataset']=='bowl':
              batch_loss = dice_loss(y,y_pred)
              
            batch_valid_DSC = dice_coef(y,y_pred)

            #print(batch_loss)
            avg_batch_valid_DSC += batch_valid_DSC.sum()/(len(batch_valid_DSC))
            loss = batch_loss.sum()/(len(batch_loss))
            valid_loss+=loss #sums up all avg batch losses

            # Calculating Accuracy:
            precision, recall = calculate_prec_rec(y, y_pred)
            pred_iou = iou(y, y_pred)

            mPrecision+=precision.sum()/(len(precision)) #mean precision of a batch and sums them up
            mRecall+=recall.sum()/(len(recall)) #mean recall of a batch and sums them up
            mIOU+=pred_iou.sum()/(len(pred_iou)) #mean IOU of a batch and sums them up

    valid_loss /= num_batches
    valid_DSC = avg_batch_valid_DSC / num_batches
    print_both('\n~~~~~~~~~~~~~~~~~ Test Loss: {:.4f} ~~~~~~~~~~~~~~~~~\n'.format(valid_loss),output_file_path = output_file_path)
    print_both('mean Precision:{}   |    mean Recall:{}   |    mIOU:{}    |   DSC:{}\n'.format(mPrecision/ num_batches, mRecall/ num_batches, mIOU/ num_batches, valid_DSC),output_file_path = output_file_path)
    
    return valid_loss.item(), valid_DSC.item(), (mPrecision/ num_batches).item(), (mRecall/ num_batches).item(), (mIOU/ num_batches).item()

# %% [markdown]
# ## 10.3 Test loaded model

# %%
'''folder_in_output from section 8.'''

model_name = 'DoubleUNet.pth'
model_path = config['output_path']+folder_in_output+model_name
test_output_path = config['output_path']+folder_in_output+'final_test'+model_name+'.txt'

device = "cuda" if torch.cuda.is_available() else "cpu"
loaded_model = load_model(model_path)
loaded_model.eval()
#print(loaded_model)
test_loss, test_DSC, test_mPrecision, test_mRecall, test_mIOU = final_test(loaded_model, test_dataloader, test_output_path)

# %%
batch = next(iter(test_dataloader))
x = batch['image'].to(device) #GPU
y = batch['mask'].to(device) # GPU
y_pred = loaded_model(x)
y_pred = torch.round(y_pred)


x = x.permute(0,2,3,1)
test_images= [cv2.cvtColor(x[i,:,:,:].cpu().detach().numpy(), cv2.COLOR_BGR2RGB) for i in range(0,config['batch_size'])]

figure = plt.figure(figsize=[15, 15])
figure.subplots_adjust(wspace=0.1, hspace=0.1)

for i in range(4):
  figure.add_subplot(4,3,3*i+1).set_aspect('equal')
  plt.title('Input')
  plt.axis('off')
  plt.imshow(test_images[i+6])
  figure.add_subplot(4,3,3*i+2).set_aspect('equal')
  plt.title('Ground Truth')
  plt.axis('off')
  plt.imshow(torchvision.utils.make_grid(y[i+6].cpu(), nrow=1).permute(1, 2, 0))
  figure.add_subplot(4,3,3*i+3).set_aspect('equal')
  plt.title('Output2')
  plt.axis('off')
  plt.imshow(torchvision.utils.make_grid(y_pred[i+6].cpu(), nrow=1).permute(1, 2, 0))

figure.subplots_adjust(wspace=0.1, hspace=0.1)

# %% [markdown]
# num of parameters:

# %%
from prettytable import PrettyTable

def count_parameters(model):
    table = PrettyTable(["Modules", "Parameters"])
    total_params = 0
    for name, parameter in model.named_parameters():
        if not parameter.requires_grad: continue
        params = parameter.numel()
        table.add_row([name, params])
        total_params+=params
    print(table)
    print(f"Total Trainable Params: {total_params}")
    return total_params
    
count_parameters(loaded_model)
